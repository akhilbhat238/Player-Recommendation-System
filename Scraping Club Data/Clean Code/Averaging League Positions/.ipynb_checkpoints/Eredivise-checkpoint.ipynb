# %%
import numpy as np
import pandas as pd

# %%
bl_07_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2007.csv')
bl_08_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2008.csv')
bl_09_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2009.csv')
bl_10_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2010.csv')
bl_11_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2011.csv')
bl_12_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2012.csv')
bl_13_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2013.csv')
bl_14_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2014.csv')
bl_15_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2015.csv')
bl_16_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2016.csv')
bl_17_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2017.csv')
bl_18_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2018.csv')
bl_19_df = pd.read_csv('..\\..\\Consolidated Data\\Eredivise_2019.csv')

# %%
current_team_list = ['Ajax',
'PSV Eindhoven',
'Twente',
'Vitesse Arnhem',
'AZ Alkmaar',
'FC Utrecht',
'Feyenoord',
'Willem II',
'VVV-Venlo',
'Heracles Almelo',
'Sparta Rotterdam',
'PEC Zwolle',
'SC Heerenveen',
'ADO Den Haag',
'FC Groningen',
'Emmen',
'Fortuna Sittard',
'Waalwijk']

# %%
bl_combined_df = pd.DataFrame(current_team_list, columns =['Team'])

# %%
bl_combined_df = bl_combined_df.merge(bl_19_df[['Team','Pos']],how='left',on='Team')

# %%
bl_combined_df = bl_combined_df.merge(bl_18_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_17_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_16_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_15_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_14_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_13_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_12_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_11_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_10_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_09_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_08_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_07_df[['Team','Pos']],how='left',on='Team')

# %%
bl_combined_df = bl_combined_df.fillna(19)
bl_combined_df.columns = ['Team','Pos_2019','Pos_2018','Pos_2017','Pos_2016','Pos_2015','Pos_2014','Pos_2013','Pos_2012','Pos_2011','Pos_2010','Pos_2009','Pos_2008','Pos_2007']

# %%
bl_combined_df['Avg_Pos'] = bl_combined_df.mean(axis=1)
bl_final_df = bl_combined_df[['Team','Avg_Pos']]
bl_final_df.to_csv('..\\..\\Consolidated Data\\Eredivise Average Positions.csv',index=False)

# %%
bl_combined_df
# Out:
#                 Team  Pos_2019  Pos_2018  Pos_2017  Pos_2016  Pos_2015  \
# 0               Ajax       1.0       2.0       2.0       2.0       2.0
# 1      PSV Eindhoven       2.0       1.0       3.0       1.0       1.0
# 2             Twente      19.0      18.0       7.0      13.0       8.0
# 3     Vitesse Arnhem       5.0       6.0       5.0       9.0       5.0
# 4         AZ Alkmaar       4.0       3.0       6.0       4.0       3.0
# 5         FC Utrecht       6.0       5.0       4.0       5.0      11.0
# 6          Feyenoord       3.0       4.0       1.0       3.0       4.0
# 7          Willem II      10.0      13.0      13.0      16.0      10.0
# 8          VVV-Venlo      12.0      15.0      19.0      19.0      19.0
# 9    Heracles Almelo       7.0      10.0      10.0       6.0      14.0
# 10  Sparta Rotterdam      19.0      17.0      15.0      19.0      19.0
# 11        PEC Zwolle      13.0       9.0      14.0       8.0       6.0
# 12     SC Heerenveen      11.0       8.0       9.0      12.0       7.0
# 13      ADO Den Haag       9.0       7.0      11.0      11.0      13.0
# 14      FC Groningen       8.0      12.0       8.0       7.0       9.0
# 15             Emmen      14.0      19.0      19.0      19.0      19.0
# 16   Fortuna Sittard      15.0      19.0      19.0      19.0      19.0
# 17          Waalwijk      19.0      19.0      19.0      19.0      19.0
#
#     Pos_2014  Pos_2013  Pos_2012  Pos_2011  Pos_2010  Pos_2009  Pos_2008  \
# 0        1.0       1.0       1.0       1.0       2.0       3.0       2.0
# 1        4.0       2.0       3.0       3.0       3.0       4.0       1.0
# 2        3.0       6.0       6.0       2.0       1.0       2.0       4.0
# 3        6.0       4.0       7.0      15.0      14.0      10.0      12.0
# 4        8.0      10.0       4.0       4.0       5.0       1.0      11.0
# 5       10.0       5.0      11.0       9.0       7.0       9.0      10.0
# 6        2.0       3.0       2.0      10.0       4.0       7.0       6.0
# 7       19.0      18.0      19.0      18.0      17.0      12.0      15.0
# 8       19.0      17.0      16.0      17.0      12.0      19.0      17.0
# 9       14.0      12.0      12.0       8.0       6.0      15.0      14.0
# 10      19.0      19.0      19.0      19.0      16.0      13.0      13.0
# 11      11.0      11.0      19.0      19.0      19.0      19.0      19.0
# 12       5.0       8.0       5.0      12.0      11.0       5.0       5.0
# 13       9.0       9.0      15.0       7.0      15.0      14.0      19.0
# 14       7.0       7.0      14.0       5.0       8.0       6.0       7.0
# 15      19.0      19.0      19.0      19.0      19.0      19.0      19.0
# 16      19.0      19.0      19.0      19.0      19.0      19.0      19.0
# 17      16.0      14.0       9.0      19.0      18.0      19.0      19.0
#
#     Pos_2007    Avg_Pos
# 0        2.0   1.692308
# 1        1.0   2.230769
# 2        4.0   7.153846
# 3       12.0   8.461538
# 4        3.0   5.076923
# 5        9.0   7.769231
# 6        7.0   4.307692
# 7       15.0  15.000000
# 8       19.0  16.923077
# 9       14.0  10.923077
# 10      13.0  16.923077
# 11      19.0  14.307692
# 12       5.0   7.923077
# 13      18.0  12.076923
# 14       8.0   8.153846
# 15      19.0  18.615385
# 16      19.0  18.692308
# 17      17.0  17.384615
