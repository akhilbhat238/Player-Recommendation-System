# %%
import numpy as np
import pandas as pd

# %%
bl_07_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2007.csv')
bl_08_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2008.csv')
bl_09_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2009.csv')
bl_10_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2010.csv')
bl_11_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2011.csv')
bl_12_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2012.csv')
bl_13_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2013.csv')
bl_14_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2014.csv')
bl_15_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2015.csv')
bl_16_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2016.csv')
bl_17_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2017.csv')
bl_18_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2018.csv')
bl_19_df = pd.read_csv('..\\..\\Consolidated Data\\La_Liga_2019.csv')

# %%
current_team_list = ['Sevilla',
'Atletico Madrid',
'Real Madrid',
'Athletic Bilbao',
'Barcelona',
'Granada',
'Real Sociedad',
'Levante',
'Osasuna',
'Villarreal',
'Alaves',
'Real Valladolid',
'Valencia',
'Real Mallorca',
'Real Betis',
'Celta de Vigo',
'Espanyol',
'Getafe',
'Eibar',
'Leganes']

# %%
bl_combined_df = pd.DataFrame(current_team_list, columns =['Team'])

# %%
bl_combined_df = bl_combined_df.merge(bl_19_df[['Team','Pos']],how='left',on='Team')

# %%
bl_combined_df = bl_combined_df.merge(bl_18_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_17_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_16_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_15_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_14_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_13_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_12_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_11_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_10_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_09_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_08_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_07_df[['Team','Pos']],how='left',on='Team')

# %%
bl_combined_df = bl_combined_df.fillna(21)
bl_combined_df.columns = ['Team','Pos_2019','Pos_2018','Pos_2017','Pos_2016','Pos_2015','Pos_2014','Pos_2013','Pos_2012','Pos_2011','Pos_2010','Pos_2009','Pos_2008','Pos_2007']

# %%
bl_combined_df['Avg_Pos'] = bl_combined_df.mean(axis=1)
bl_final_df = bl_combined_df[['Team','Avg_Pos']]
bl_final_df.to_csv('..\\..\\Consolidated Data\\La Liga Average Positions.csv',index=False)

# %%
bl_combined_df
# Out:
#                Team  Pos_2019  Pos_2018  Pos_2017  Pos_2016  Pos_2015  \
# 0           Sevilla       6.0       7.0       4.0       7.0       5.0
# 1   Atletico Madrid       2.0       2.0       3.0       3.0       3.0
# 2       Real Madrid       3.0       3.0       1.0       2.0       2.0
# 3   Athletic Bilbao       8.0      16.0       7.0       5.0       7.0
# 4         Barcelona       1.0       1.0       2.0       1.0       1.0
# 5           Granada      21.0      21.0      20.0      16.0      17.0
# 6     Real Sociedad       9.0      12.0       6.0       9.0      12.0
# 7           Levante      15.0      15.0      21.0      20.0      14.0
# 8           Osasuna      21.0      21.0      19.0      21.0      21.0
# 9        Villarreal      14.0       5.0       5.0       4.0       6.0
# 10           Alaves      11.0      14.0       9.0      21.0      21.0
# 11  Real Valladolid      16.0      21.0      21.0      21.0      21.0
# ...
