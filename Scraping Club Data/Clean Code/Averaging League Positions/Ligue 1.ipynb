# %%
import numpy as np
import pandas as pd

# %%
bl_07_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2007.csv')
bl_08_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2008.csv')
bl_09_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2009.csv')
bl_10_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2010.csv')
bl_11_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2011.csv')
bl_12_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2012.csv')
bl_13_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2013.csv')
bl_14_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2014.csv')
bl_15_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2015.csv')
bl_16_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2016.csv')
bl_17_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2017.csv')
bl_18_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2018.csv')
bl_19_df = pd.read_csv('..\\..\\Consolidated Data\\Ligue1_2019.csv')

# %%
current_team_list = ['Amiens',
'Angers',
'Bordeaux',
'Brest',
'Dijon',
'Lille',
'Marseille',
'Metz',
'Monaco',
'Montpellier',
'Nantes',
'Nice',
'Nimes',
'Olympique Lyonnais',
'Paris Saint Germain',
'Reims',
'Rennes',
'St Etienne',
'Strasbourg',
'Toulouse']

# %%
bl_combined_df = pd.DataFrame(current_team_list, columns =['Team'])

# %%
bl_combined_df = bl_combined_df.merge(bl_19_df[['Team','Pos']],how='left',on='Team')

# %%
bl_combined_df = bl_combined_df.merge(bl_18_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_17_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_16_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_15_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_14_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_13_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_12_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_11_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_10_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_09_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_08_df[['Team','Pos']],how='left',on='Team')
bl_combined_df = bl_combined_df.merge(bl_07_df[['Team','Pos']],how='left',on='Team')

# %%
bl_combined_df = bl_combined_df.fillna(21)
bl_combined_df.columns = ['Team','Pos_2019','Pos_2018','Pos_2017','Pos_2016','Pos_2015','Pos_2014','Pos_2013','Pos_2012','Pos_2011','Pos_2010','Pos_2009','Pos_2008','Pos_2007']

# %%
bl_combined_df['Avg_Pos'] = bl_combined_df.mean(axis=1)
bl_final_df = bl_combined_df[['Team','Avg_Pos']]
bl_final_df.to_csv('..\\..\\Consolidated Data\\Ligue 1 Average Positions.csv',index=False)

# %%
bl_combined_df
# Out:
#                    Team  Pos_2019  Pos_2018  Pos_2017  Pos_2016  Pos_2015  \
# 0                Amiens      15.0      13.0      21.0      21.0      21.0
# 1                Angers      13.0      14.0      12.0       9.0      21.0
# 2              Bordeaux      14.0       6.0       6.0      11.0       6.0
# 3                 Brest      21.0      21.0      21.0      21.0      21.0
# 4                 Dijon      18.0      11.0      16.0      21.0      21.0
# 5                 Lille       2.0      17.0      11.0       5.0       8.0
# 6             Marseille       5.0       4.0       5.0      13.0       4.0
# 7                  Metz      21.0      20.0      14.0      21.0      19.0
# 8                Monaco      17.0       2.0       1.0       3.0       3.0
# 9           Montpellier       6.0      10.0      15.0      12.0       7.0
# 10               Nantes      12.0       9.0       7.0      14.0      14.0
# 11                 Nice       7.0       8.0       3.0       4.0      11.0
# 12                Nimes       9.0      21.0      21.0      21.0      21.0
# 13   Olympique Lyonnais       3.0       3.0       4.0       2.0       2.0
# 14  Paris Saint Germain       1.0       1.0       2.0       1.0       1.0
# 15                Reims       8.0      21.0      21.0      18.0      15.0
# 16               Rennes      10.0       5.0       9.0       8.0       9.0
# 17           St Etienne       4.0       7.0       8.0       6.0       5.0
# 18           Strasbourg      11.0      15.0      21.0      21.0      21.0
# 19             Toulouse      16.0      18.0      13.0      17.0      17.0
#
#     Pos_2014  Pos_2013  Pos_2012  Pos_2011  Pos_2010  Pos_2009  Pos_2008  \
# 0       21.0      21.0      21.0      21.0      21.0      21.0      21.0
# 1       21.0      21.0      21.0      21.0      21.0      21.0      21.0
# 2        7.0       7.0       5.0       7.0       6.0       1.0       2.0
# 3       21.0      20.0      15.0      16.0      21.0      21.0      21.0
# 4       21.0      21.0      19.0      21.0      21.0      21.0      21.0
# 5        3.0       6.0       3.0       1.0       4.0       5.0       7.0
# 6        6.0       2.0      10.0       2.0       1.0       2.0       3.0
# 7       21.0      21.0      21.0      21.0      21.0      21.0      20.0
# 8        2.0      21.0      21.0      18.0       8.0      11.0      12.0
# 9       15.0       9.0       1.0      14.0       5.0      21.0      21.0
# 10       8.0      21.0      21.0      21.0      21.0      19.0      21.0
# 11      17.0       4.0      13.0      17.0      15.0       9.0       8.0
# 12      21.0      21.0      21.0      21.0      21.0      21.0      21.0
# 13       5.0       3.0       4.0       3.0       2.0       3.0       1.0
# 14       1.0       1.0       2.0       4.0      13.0       6.0      16.0
# 15      11.0      14.0      21.0      21.0      21.0      21.0      21.0
# 16      12.0      13.0       6.0       6.0       9.0       7.0       6.0
# 17       4.0       5.0       7.0      10.0      17.0      17.0       5.0
# 18      21.0      21.0      21.0      21.0      21.0      21.0      19.0
# 19      10.0      10.0       8.0       8.0      14.0       4.0      17.0
#
#     Pos_2007    Avg_Pos
# 0       21.0  19.923077
# 1       21.0  18.230769
# 2        6.0   6.461538
# 3       21.0  20.076923
# 4       21.0  19.461538
# 5       10.0   6.307692
# 6        2.0   4.538462
# 7       21.0  20.153846
# 8        9.0   9.846154
# 9       21.0  12.076923
# 10      20.0  16.000000
# 11      16.0  10.153846
# 12      21.0  20.076923
# 13       1.0   2.769231
# 14      15.0   4.923077
# 15      21.0  18.000000
# 16       4.0   8.000000
# 17      11.0   8.153846
# 18      21.0  19.615385
# 19       3.0  11.923077
