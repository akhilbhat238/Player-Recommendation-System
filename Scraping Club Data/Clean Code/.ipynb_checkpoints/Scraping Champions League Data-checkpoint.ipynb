# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
#Use Beautiful Soup to pull all contents of the web-page
page = requests.get('https://en.wikipedia.org/wiki/European_Cup_and_UEFA_Champions_League_records_and_statistics')
soup = BeautifulSoup(page.content,'html.parser')

#Find all tables in the page
tables = soup.findAll("table")

# %%
table_header = tables[0].findAll("tr")
header_list=[]

# %%
for i in range(1,len(table_header[0])):
    if(i==1):
        header_list.append(table_header[0].contents[i].contents[1].lstrip().rstrip())
    elif (i%2 != 0):
        header_list.append(table_header[0].contents[i].contents[0].lstrip().rstrip())

# %%
cl_final_record = pd.DataFrame(columns=header_list)
rows = tables[0].findAll("tr")

# %%
for club in range(1,len(rows)):
    club_name = rows[club].contents[1].contents[2].contents[0]
    titles = rows[club].contents[3].contents[0].rstrip()
    runners = rows[club].contents[5].contents[0].rstrip()
    x = rows[club].contents[7].findAll("a")
    win_list = []
    for i in range(0,len(x)):
        win_list.append(x[i].contents[0])
    y = rows[club].contents[9].findAll("a")
    runner_list = []
    for j in range(0,len(y)):
        runner_list.append(y[j].contents[0])
    cl_final_record.loc[club-1] = [club_name,titles,runners,win_list,runner_list]

# %%
semi_table_hdr = tables[4].findAll("tr")
semi_hdr_list = []

# %%
for i in range(1,len(semi_table_hdr[0])):
    if (i%2 != 0):
        semi_hdr_list.append(semi_table_hdr[0].contents[i].contents[0].lstrip().rstrip())

# %%
cl_semi_record = pd.DataFrame(columns=semi_hdr_list)
rows = tables[4].findAll("tr")

# %%
for club in range(1,len(rows)):
    club_name = rows[club].contents[1].contents[2].contents[0]
    number_of_semis = rows[club].contents[3].contents[0].rstrip()
    x = rows[club].contents[5].findAll("a")
    years = []
    for i in range(0,len(x)):
        years.append(x[i].contents[0])
    cl_semi_record.loc[club-1] = [club_name,number_of_semis,years]

# %%
season_dict={}
for i in range(0,len(cl_final_record)):
    club_name = cl_final_record['Club'][i]
    winning_list = cl_final_record[cl_final_record.Club == club_name]['Seasons won'].tolist()
    for i in range(0,len(winning_list)):
            season_list = winning_list[i]
            if(len(season_list)!=0):
                for i in season_list:
                    season_dict[i] = [club_name]

# %%
for i in range(0,len(cl_final_record)):
    club_name = cl_final_record['Club'][i]
    runner_list = cl_final_record[cl_final_record.Club == club_name]['Seasons runner-up'].tolist()
    for i in range(0,len(runner_list)):
            season_list = runner_list[i]
            if(len(season_list)!=0):
                for i in season_list:
                    season_dict[i].append(club_name)

# %%
teams = cl_semi_record['Team']

# %%
for team in teams:
    season_list=[]
    team_list = cl_semi_record[cl_semi_record['Team']==team]['Years']
    team_index = team_list.index[0]
    season_list = team_list[team_index]
    for season in season_list:
        if(team!=season_dict[season][0]):
            if(team!=season_dict[season][1]):
                season_dict[season].append(team)
# Out:
# Checking for: Real Madrid
# 1956
# Real Madrid
# 1957
# Real Madrid
# 1958
# Real Madrid
# 1959
# Real Madrid
# 1960
# Real Madrid
# 1962
# Benfica
# Not a winner
# 1964
# Internazionale
# Not a winner
# 1966
# Real Madrid
# 1968
# Manchester United
# Not a winner
# Not a runner
# 1973
# Ajax
# Not a winner
# Not a runner
# 1976
# Bayern Munich
# Not a winner
# Not a runner
# 1980
# Nottingham Forest
# Not a winner
# Not a runner
# 1981
# Liverpool
# Not a winner
# 1987
# Porto
# Not a winner
# Not a runner
# 1988
# PSV Eindhoven
# Not a winner
# Not a runner
# 1989
# Milan
# Not a winner
# Not a runner
# 1998
# Real Madrid
# 2000
# Real Madrid
# 2001
# Bayern Munich
# Not a winner
# Not a runner
# 2002
# Real Madrid
# 2003
# Milan
# Not a winner
# Not a runner
# 2011
# Barcelona
# Not a winner
# Not a runner
# 2012
# Chelsea
# Not a winner
# Not a runner
# 2013
# Bayern Munich
# Not a winner
# Not a runner
# 2014
# Real Madrid
# 2015
# Barcelona
# Not a winner
# Not a runner
# 2016
# Real Madrid
# 2017
# Real Madrid
# 2018
# Real Madrid
# Checking for: Bayern Munich
# 1974
# Bayern Munich
# 1975
# Bayern Munich
# 1976
# Bayern Munich
# 1981
# Liverpool
# Not a winner
# Not a runner
# 1982
# Aston Villa
# Not a winner
# 1987
# Porto
# Not a winner
# 1990
# Milan
# Not a winner
# Not a runner
# 1991
# Red Star Belgrade
# Not a winner
# Not a runner
# 1995
# Ajax
# Not a winner
# Not a runner
# 1999
# Manchester United
# Not a winner
# 2000
# Real Madrid
# Not a winner
# Not a runner
# 2001
# Bayern Munich
# 2010
# Internazionale
# Not a winner
# 2012
# Chelsea
# Not a winner
# 2013
# Bayern Munich
# 2014
# Real Madrid
# Not a winner
# Not a runner
# 2015
# Barcelona
# Not a winner
# Not a runner
# 2016
# Real Madrid
# Not a winner
# Not a runner
# 2018
# Real Madrid
# Not a winner
# Not a runner
# Checking for: Barcelona
# 1960
# Real Madrid
# Not a winner
# Not a runner
# 1961
# Benfica
# Not a winner
# 1975
# Bayern Munich
# Not a winner
# Not a runner
# 1986
# Steaua București
# Not a winner
# 1992
# Barcelona
# 1994
# Milan
# Not a winner
# 2000
# Real Madrid
# Not a winner
# Not a runner
# 2002
# Real Madrid
# Not a winner
# Not a runner
# 2006
# Barcelona
# 2008
# Manchester United
# Not a winner
# Not a runner
# 2009
# Barcelona
# 2010
# Internazionale
# Not a winner
# Not a runner
# 2011
# Barcelona
# 2012
# Chelsea
# Not a winner
# Not a runner
# 2013
# Bayern Munich
# Not a winner
# Not a runner
# 2015
# Barcelona
# 2019
# Liverpool
# Not a winner
# Not a runner
# Checking for: Milan
# 1956
# Real Madrid
# Not a winner
# Not a runner
# 1958
# Real Madrid
# Not a winner
# 1963
# Milan
# 1969
# Milan
# 1989
# Milan
# 1990
# Milan
# 1993
# Marseille
# Not a winner
# 1994
# Milan
# 1995
# Ajax
# Not a winner
# 2003
# Milan
# 2005
# Liverpool
# Not a winner
# 2006
# Barcelona
# Not a winner
# Not a runner
# 2007
# Milan
# Checking for: Manchester United
# 1957
# Real Madrid
# Not a winner
# Not a runner
# 1958
# Real Madrid
# Not a winner
# Not a runner
# 1966
# Real Madrid
# Not a winner
# Not a runner
# 1968
# Manchester United
# 1969
# Milan
# Not a winner
# Not a runner
# 1997
# Borussia Dortmund
# Not a winner
# Not a runner
# 1999
# Manchester United
# 2002
# Real Madrid
# Not a winner
# Not a runner
# 2007
# Milan
# Not a winner
# Not a runner
# 2008
# Manchester United
# 2009
# Barcelona
# Not a winner
# 2011
# Barcelona
# Not a winner
# Checking for: Juventus
# 1968
# Manchester United
# Not a winner
# Not a runner
# 1973
# Ajax
# Not a winner
# 1978
# Liverpool
# Not a winner
# Not a runner
# 1983
# Hamburger SV
# Not a winner
# 1985
# Juventus
# 1996
# Juventus
# 1997
# Borussia Dortmund
# Not a winner
# 1998
# Real Madrid
# Not a winner
# 1999
# Manchester United
# Not a winner
# Not a runner
# 2003
# Milan
# Not a winner
# 2015
# Barcelona
# Not a winner
# 2017
# Real Madrid
# Not a winner
# Checking for: Liverpool
# 1965
# Internazionale
# Not a winner
# Not a runner
# 1977
# Liverpool
# 1978
# Liverpool
# 1981
# Liverpool
# 1984
# Liverpool
# 1985
# Juventus
# Not a winner
# 2005
# Liverpool
# 2007
# Milan
# Not a winner
# 2008
# Manchester United
# Not a winner
# Not a runner
# 2018
# Real Madrid
# Not a winner
# 2019
# Liverpool
# Checking for: Ajax
# 1969
# Milan
# Not a winner
# 1971
# Ajax
# 1972
# Ajax
# 1973
# Ajax
# 1980
# Nottingham Forest
# Not a winner
# Not a runner
# 1995
# Ajax
# 1996
# Juventus
# Not a winner
# 1997
# Borussia Dortmund
# Not a winner
# Not a runner
# 2019
# Liverpool
# Not a winner
# Not a runner
# Checking for: Benfica
# 1961
# Benfica
# 1962
# Benfica
# 1963
# Milan
# Not a winner
# 1965
# Internazionale
# Not a winner
# 1968
# Manchester United
# Not a winner
# 1972
# Ajax
# Not a winner
# Not a runner
# 1988
# PSV Eindhoven
# Not a winner
# 1990
# Milan
# Not a winner
# Checking for: Inter Milan
# 1964
# Internazionale
# Not a winner
# Not a runner
# 1965
# Internazionale
# Not a winner
# Not a runner
# 1966
# Real Madrid
# Not a winner
# Not a runner
# 1967
# Celtic
# Not a winner
# Not a runner
# 1972
# Ajax
# Not a winner
# Not a runner
# 1981
# Liverpool
# Not a winner
# Not a runner
# 2003
# Milan
# Not a winner
# Not a runner
# 2010
# Internazionale
# Not a winner
# Not a runner
# Checking for: Chelsea
# 2004
# Porto
# Not a winner
# Not a runner
# 2005
# Liverpool
# Not a winner
# Not a runner
# 2007
# Milan
# Not a winner
# Not a runner
# 2008
# Manchester United
# Not a winner
# 2009
# Barcelona
# Not a winner
# Not a runner
# 2012
# Chelsea
# 2014
# Real Madrid
# Not a winner
# Not a runner
# Checking for: Atlético Madrid
# 1959
# Real Madrid
# Not a winner
# Not a runner
# 1971
# Ajax
# Not a winner
# Not a runner
# 1974
# Bayern Munich
# Not a winner
# 2014
# Real Madrid
# Not a winner
# 2016
# Real Madrid
# Not a winner
# 2017
# Real Madrid
# Not a winner
# Not a runner
# Checking for: Red Star Belgrade
# 1957
# Real Madrid
# Not a winner
# Not a runner
# 1971
# Ajax
# Not a winner
# Not a runner
# 1991
# Red Star Belgrade
# 1992
# Barcelona
# Not a winner
# Not a runner
# Checking for: Borussia Dortmund
# 1964
# Internazionale
# Not a winner
# Not a runner
# 1997
# Borussia Dortmund
# 1998
# Real Madrid
# Not a winner
# Not a runner
# 2013
# Bayern Munich
# Not a winner
# Checking for: Celtic
# 1967
# Celtic
# 1970
# Feyenoord
# Not a winner
# 1972
# Ajax
# Not a winner
# Not a runner
# 1974
# Bayern Munich
# Not a winner
# Not a runner
# Checking for: Monaco
# 1994
# Milan
# Not a winner
# Not a runner
# 1998
# Real Madrid
# Not a winner
# Not a runner
# 2004
# Porto
# Not a winner
# 2017
# Real Madrid
# Not a winner
# Not a runner
# Checking for: Hamburg
# 1961
# Benfica
# Not a winner
# Not a runner
# 1980
# Nottingham Forest
# Not a winner
# Not a runner
# 1983
# Hamburger SV
# Not a winner
# Not a runner
# Checking for: Leeds United
# 1970
# Feyenoord
# Not a winner
# Not a runner
# 1975
# Bayern Munich
# Not a winner
# 2001
# Bayern Munich
# Not a winner
# Not a runner
# Checking for: Panathinaikos
# 1971
# Ajax
# Not a winner
# 1985
# Juventus
# Not a winner
# Not a runner
# 1996
# Juventus
# Not a winner
# Not a runner
# Checking for: PSV Eindhoven
# 1976
# Bayern Munich
# Not a winner
# Not a runner
# 1988
# PSV Eindhoven
# 2005
# Liverpool
# Not a winner
# Not a runner
# Checking for: Dynamo Kyiv
# 1977
# Liverpool
# Not a winner
# Not a runner
# 1987
# Porto
# Not a winner
# Not a runner
# 1999
# Manchester United
# Not a winner
# Not a runner
# Checking for: Steaua București
# 1986
# Steaua București
# 1988
# PSV Eindhoven
# Not a winner
# Not a runner
# 1989
# Milan
# Not a winner
# Checking for: Porto
# 1987
# Porto
# 1994
# Milan
# Not a winner
# Not a runner
# 2004
# Porto
# Checking for: Marseille
# 1990
# Milan
# Not a winner
# Not a runner
# 1991
# Red Star Belgrade
# Not a winner
# 1993
# Marseille
# Checking for: Reims
# 1956
# Real Madrid
# Not a winner
# 1959
# Real Madrid
# Not a winner
# Checking for: Rangers
# 1960
# Real Madrid
# Not a winner
# Not a runner
# 1993
# Marseille
# Not a winner
# Not a runner
# Checking for: Tottenham Hotspur
# 1962
# Benfica
# Not a winner
# Not a runner
# 2019
# Liverpool
# Not a winner
# Checking for: Feyenoord
# 1963
# Milan
# Not a winner
# Not a runner
# 1970
# Feyenoord
# Checking for: Zürich
# 1964
# Internazionale
# Not a winner
# Not a runner
# 1977
# Liverpool
# Not a winner
# Not a runner
# Checking for: CSKA Sofia
# 1967
# Celtic
# Not a winner
# Not a runner
# 1982
# Aston Villa
# Not a winner
# Not a runner
# Checking for: Saint-Étienne
# 1975
# Bayern Munich
# Not a winner
# Not a runner
# 1976
# Bayern Munich
# Not a winner
# Checking for: Borussia Mönchengladbach
# 1977
# Liverpool
# Not a winner
# 1978
# Liverpool
# Not a winner
# Not a runner
# Checking for: Nottingham Forest
# 1979
# Nottingham Forest
# 1980
# Nottingham Forest
# Checking for: Anderlecht
# 1982
# Aston Villa
# Not a winner
# Not a runner
# 1986
# Steaua București
# Not a winner
# Not a runner
# Checking for: Roma
# 1984
# Liverpool
# Not a winner
# 2018
# Real Madrid
# Not a winner
# Not a runner
# Checking for: IFK Göteborg
# 1986
# Steaua București
# Not a winner
# Not a runner
# 1993
# Marseille
# Not a winner
# Not a runner
# Checking for: Valencia
# 2000
# Real Madrid
# Not a winner
# 2001
# Bayern Munich
# Not a winner
# Checking for: Arsenal
# 2006
# Barcelona
# Not a winner
# 2009
# Barcelona
# Not a winner
# Not a runner
# Checking for: Hibernian
# 1956
# Real Madrid
# Not a winner
# Not a runner
# Checking for: Fiorentina
# 1957
# Real Madrid
# Not a winner
# Checking for: Vasas
# 1958
# Real Madrid
# Not a winner
# Not a runner
# Checking for: Young Boys
# 1959
# Real Madrid
# Not a winner
# Not a runner
# Checking for: Eintracht Frankfurt
# 1960
# Real Madrid
# Not a winner
# Checking for: Rapid Wien
# 1961
# Benfica
# Not a winner
# Not a runner
# Checking for: Standard Liège
# 1962
# Benfica
# Not a winner
# Not a runner
# Checking for: Dundee
# 1963
# Milan
# Not a winner
# Not a runner
# Checking for: Győri ETO
# 1965
# Internazionale
# Not a winner
# Not a runner
# Checking for: Partizan
# 1966
# Real Madrid
# Not a winner
# Checking for: Dukla Praha
# 1967
# Celtic
# Not a winner
# Not a runner
# Checking for: Spartak Trnava
# 1969
# Milan
# Not a winner
# Not a runner
# Checking for: Legia Warsaw
# 1970
# Feyenoord
# Not a winner
# Not a runner
# Checking for: Derby County
# 1973
# Ajax
# Not a winner
# Not a runner
# Checking for: Újpest
# 1974
# Bayern Munich
# Not a winner
# Not a runner
# Checking for: Club Brugge
# 1978
# Liverpool
# Not a winner
# Checking for: Austria Wien
# 1979
# Nottingham Forest
# Not a winner
# Not a runner
# Checking for: Köln
# 1979
# Nottingham Forest
# Not a winner
# Not a runner
# Checking for: Malmö FF
# 1979
# Nottingham Forest
# Not a winner
# Checking for: Aston Villa
# 1982
# Aston Villa
# Checking for: Real Sociedad
# 1983
# Hamburger SV
# Not a winner
# Not a runner
# Checking for: Widzew Łódź
# 1983
# Hamburger SV
# Not a winner
# Not a runner
# Checking for: Dinamo București
# 1984
# Liverpool
# Not a winner
# Not a runner
# Checking for: Dundee United
# 1984
# Liverpool
# Not a winner
# Not a runner
# Checking for: Bordeaux
# 1985
# Juventus
# Not a winner
# Not a runner
# Checking for: Galatasaray
# 1989
# Milan
# Not a winner
# Not a runner
# Checking for: Spartak Moscow
# 1991
# Red Star Belgrade
# Not a winner
# Not a runner
# Checking for: Sparta Prague
# 1992
# Barcelona
# Not a winner
# Not a runner
# Checking for: Sampdoria
# 1992
# Barcelona
# Not a winner
# Checking for: Paris Saint-Germain
# 1995
# Ajax
# Not a winner
# Not a runner
# Checking for: Nantes
# 1996
# Juventus
# Not a winner
# Not a runner
# Checking for: Bayer Leverkusen
# 2002
# Real Madrid
# Not a winner
# Checking for: Deportivo La Coruña
# 2004
# Porto
# Not a winner
# Not a runner
# Checking for: Villarreal
# 2006
# Barcelona
# Not a winner
# Not a runner
# Checking for: Lyon
# 2010
# Internazionale
# Not a winner
# Not a runner
# Checking for: Schalke 04
# 2011
# Barcelona
# Not a winner
# Not a runner
# Checking for: Manchester City
# 2016
# Real Madrid
# Not a winner
# Not a runner

# %%
season_dict_items = season_dict.items()

# %%
for i in season_dict_items:
    if (len(i[1])>4):
        if((season_dict[i[0]][2][0:5]==season_dict[i[0]][0][0:5]) or (season_dict[i[0]][2][0:5]==season_dict[i[0]][1][0:5])):
            season_dict[i[0]].remove(season_dict[i[0]][2])
        elif((season_dict[i[0]][3][0:5]==season_dict[i[0]][0][0:5]) or (season_dict[i[0]][3][0:5]==season_dict[i[0]][1][0:5])):
            season_dict[i[0]].remove(season_dict[i[0]][3])
        elif((season_dict[i[0]][4][0:5]==season_dict[i[0]][0][0:5]) or (season_dict[i[0]][4][0:5]==season_dict[i[0]][1][0:5])):
            season_dict[i[0]].remove(season_dict[i[0]][4])
# Out:
# ['Ajax', 'Internazionale', 'Benfica', 'Inter Milan', 'Celtic']
# ['Internazionale', 'Real Madrid', 'Inter Milan', 'Borussia Dortmund', 'Zürich']
# ['Internazionale', 'Benfica', 'Liverpool', 'Inter Milan', 'Győri ETO']
# ['Internazionale', 'Bayern Munich', 'Barcelona', 'Inter Milan', 'Lyon']
# ['Nottingham Forest', 'Hamburger SV', 'Real Madrid', 'Ajax', 'Hamburg']
# ['Celtic', 'Internazionale', 'Inter Milan', 'CSKA Sofia', 'Dukla Praha']
# ['Hamburger SV', 'Juventus', 'Hamburg', 'Real Sociedad', 'Widzew Łódź']

# %%
champions_league_data = pd.DataFrame(list(season_dict.items()))

# %%
champions_league_data.columns = ['Season','Teams']

# %%
winner_list=[]
runner_list=[]
sf1_list=[]
sf2_list=[]
for i in range(0,len(champions_league_data)):
    winner_list.append(champions_league_data.Teams[i][0])
    runner_list.append(champions_league_data.Teams[i][1])
    sf1_list.append(champions_league_data.Teams[i][2])
    sf2_list.append(champions_league_data.Teams[i][3])
champions_league_data['Winners'] = winner_list
champions_league_data['Runner Up'] = runner_list
champions_league_data['SF1'] = sf1_list
champions_league_data['SF2'] = sf2_list

# %%
champions_league_data = champions_league_data.drop(columns='Teams')
champions_league_data = champions_league_data.sort_values('Season')
champions_league_data = champions_league_data.set_index('Season')

# %%
champions_league_data
# Out:
#             Winners            Runner Up                SF1                SF2
# Season
# 1956    Real Madrid                Reims              Milan          Hibernian
# 1957    Real Madrid           Fiorentina  Manchester United  Red Star Belgrade
# 1958    Real Madrid                Milan  Manchester United              Vasas
# 1959    Real Madrid                Reims    Atlético Madrid         Young Boys
# 1960    Real Madrid  Eintracht Frankfurt          Barcelona            Rangers
# ...             ...                  ...                ...                ...
# 2015      Barcelona             Juventus        Real Madrid      Bayern Munich
# 2016    Real Madrid      Atlético Madrid      Bayern Munich    Manchester City
# 2017    Real Madrid             Juventus    Atlético Madrid             Monaco
# 2018    Real Madrid            Liverpool      Bayern Munich               Roma
# 2019      Liverpool    Tottenham Hotspur          Barcelona               Ajax
#
# [64 rows x 4 columns]
