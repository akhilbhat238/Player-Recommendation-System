# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get("https://thefishy.co.uk/leaguetable.php?table=79&season=16")
soup = BeautifulSoup(page.content,'html.parser')

# %%
tables = soup.findAll("table")

# %%
table_to_use = tables[5]

# %%
table_header = table_to_use.find_all('th')

# %%
header_list = []
for i in table_header:
    header_list.append(i.contents[0])

# %%
header_list
# Out:
# ['Pos', 'Team', 'P', 'W', 'D', 'L', 'F', 'A', 'GD', 'Pts']

# %%
table_data = table_to_use.find_all('td')

# %%
table_data_clean = []
for i in table_data:
    table_data_clean.append(i.contents[0])

# %%
table_data_clean
# Out:
# ['1',
#  <a href="team.php?team=Galatasaray">Galatasaray</a>,
#  '34',
#  '20',
#  '9',
#  '5',
#  '72',
#  '36',
#  '+36',
#  '69',
#  '2',
#  <a href="team.php?team=Istanbul+Basaksehir">Istanbul Basaksehir</a>,
#  '34',
#  '19',
#  '10',
#  '5',
#  '49',
#  '22',
#  '+27',
#  '67',
#  '3',
#  <a href="team.php?team=Besiktas">Besiktas</a>,
#  '34',
#  '19',
#  '8',
#  '7',
#  '72',
#  '46',
#  '+26',
#  '65',
#  '4',
#  <a href="team.php?team=Trabzonspor">Trabzonspor</a>,
#  '34',
#  '18',
#  '9',
#  '7',
#  '64',
#  '46',
#  '+18',
#  '63',
#  '5',
#  <a href="team.php?team=Yeni+Malatyaspor">Yeni Malatyaspor</a>,
#  '34',
#  '13',
#  '8',
#  '13',
#  '47',
#  '46',
#  '+1',
#  '47',
#  '6',
#  <a href="team.php?team=Fenerbahce">Fenerbahce</a>,
#  '34',
#  '11',
#  '13',
#  '10',
#  '44',
#  '44',
#  '+0',
#  '46',
#  '7',
#  <a href="team.php?team=Antalyaspor">Antalyaspor</a>,
#  '34',
#  '13',
#  '6',
#  '15',
#  '39',
#  '55',
#  '-16',
#  '45',
#  '8',
#  <a href="team.php?team=Konyaspor">Konyaspor</a>,
#  '34',
#  '9',
#  '17',
#  '8',
#  '40',
#  '38',
#  '+2',
#  '44',
#  '9',
#  <a href="team.php?team=Alanyaspor">Alanyaspor</a>,
#  '34',
#  '12',
#  '8',
#  '14',
#  '37',
#  '43',
#  '-6',
#  '44',
#  '10',
#  <a href="team.php?team=Caykur+Rizespor">Caykur Rizespor</a>,
#  '34',
#  '9',
#  '14',
#  '11',
#  '48',
#  '50',
#  '-2',
#  '41',
#  '11',
#  <a href="team.php?team=Sivasspor">Sivasspor</a>,
#  '34',
#  '10',
#  '11',
#  '13',
#  '49',
#  '54',
#  '-5',
#  '41',
#  '12',
#  <a href="team.php?team=Kayserispor">Kayserispor</a>,
#  '34',
#  '10',
#  '11',
#  '13',
#  '35',
#  '50',
#  '-15',
#  '41',
#  '13',
#  <a href="team.php?team=Ankaragucu">Ankaragucu</a>,
#  '34',
#  '11',
#  '7',
#  '16',
#  '38',
#  '53',
#  '-15',
#  '40',
#  '14',
#  <a href="team.php?team=Kasimpasa">Kasimpasa</a>,
#  '34',
#  '11',
#  '6',
#  '17',
#  '53',
#  '62',
#  '-9',
#  '39',
#  '15',
#  <a href="team.php?team=Goztepe">Goztepe</a>,
#  '34',
#  '11',
#  '5',
#  '18',
#  '37',
#  '42',
#  '-5',
#  '38',
#  '16',
#  <a href="team.php?team=Bursaspor">Bursaspor</a>,
#  '34',
#  '7',
#  '16',
#  '11',
#  '28',
#  '37',
#  '-9',
#  '37',
#  '17',
#  <a href="team.php?team=Erzurum+Buyuksehir+Belediyespor">Erzurum Buyuksehir Belediyespor</a>,
#  '34',
#  '8',
#  '11',
#  '15',
#  '36',
#  '43',
#  '-7',
#  '35',
#  '18',
#  <a href="team.php?team=Akhisar+Belediye">Akhisar Belediye</a>,
#  '34',
#  '6',
#  '9',
#  '19',
#  '33',
#  '54',
#  '-21',
#  '27']

# %%
inner_list=[]
for i in range(0,10):
    inner_list.append(table_data_clean[i])

# %%
def divide_chunks(l, n): 
    for i in range(0, len(l), n):  
        yield l[i:i + n]

# %%
n = 10  
x = list(divide_chunks(table_data_clean, n))

# %%
df = pd.DataFrame(x, columns =header_list)

# %%
df
# Out:
#    Pos                                               Team   P   W   D   L   F  \
# 0    1  <a href="team.php?team=Galatasaray">Galatasara...  34  20   9   5  72
# 1    2  <a href="team.php?team=Istanbul+Basaksehir">Is...  34  19  10   5  49
# 2    3      <a href="team.php?team=Besiktas">Besiktas</a>  34  19   8   7  72
# 3    4  <a href="team.php?team=Trabzonspor">Trabzonspo...  34  18   9   7  64
# 4    5  <a href="team.php?team=Yeni+Malatyaspor">Yeni ...  34  13   8  13  47
# 5    6  <a href="team.php?team=Fenerbahce">Fenerbahce</a>  34  11  13  10  44
# 6    7  <a href="team.php?team=Antalyaspor">Antalyaspo...  34  13   6  15  39
# 7    8    <a href="team.php?team=Konyaspor">Konyaspor</a>  34   9  17   8  40
# 8    9  <a href="team.php?team=Alanyaspor">Alanyaspor</a>  34  12   8  14  37
# 9   10  <a href="team.php?team=Caykur+Rizespor">Caykur...  34   9  14  11  48
# 10  11    <a href="team.php?team=Sivasspor">Sivasspor</a>  34  10  11  13  49
# 11  12  <a href="team.php?team=Kayserispor">Kayserispo...  34  10  11  13  35
# 12  13  <a href="team.php?team=Ankaragucu">Ankaragucu</a>  34  11   7  16  38
# 13  14    <a href="team.php?team=Kasimpasa">Kasimpasa</a>  34  11   6  17  53
# 14  15        <a href="team.php?team=Goztepe">Goztepe</a>  34  11   5  18  37
# 15  16    <a href="team.php?team=Bursaspor">Bursaspor</a>  34   7  16  11  28
# 16  17  <a href="team.php?team=Erzurum+Buyuksehir+Bele...  34   8  11  15  36
# 17  18  <a href="team.php?team=Akhisar+Belediye">Akhis...  34   6   9  19  33
#
#      A   GD Pts
# 0   36  +36  69
# 1   22  +27  67
# 2   46  +26  65
# 3   46  +18  63
# 4   46   +1  47
# 5   44   +0  46
# 6   55  -16  45
# 7   38   +2  44
# 8   43   -6  44
# 9   50   -2  41
# 10  54   -5  41
# 11  50  -15  41
# 12  53  -15  40
# 13  62   -9  39
# 14  42   -5  38
# 15  37   -9  37
# 16  43   -7  35
# 17  54  -21  27

# %%
df_team = df['Team']

# %%
df_team
# Out:
# 0     <a href="team.php?team=Galatasaray">Galatasara...
# 1     <a href="team.php?team=Istanbul+Basaksehir">Is...
# 2         <a href="team.php?team=Besiktas">Besiktas</a>
# 3     <a href="team.php?team=Trabzonspor">Trabzonspo...
# 4     <a href="team.php?team=Yeni+Malatyaspor">Yeni ...
# 5     <a href="team.php?team=Fenerbahce">Fenerbahce</a>
# 6     <a href="team.php?team=Antalyaspor">Antalyaspo...
# 7       <a href="team.php?team=Konyaspor">Konyaspor</a>
# 8     <a href="team.php?team=Alanyaspor">Alanyaspor</a>
# 9     <a href="team.php?team=Caykur+Rizespor">Caykur...
# 10      <a href="team.php?team=Sivasspor">Sivasspor</a>
# 11    <a href="team.php?team=Kayserispor">Kayserispo...
# 12    <a href="team.php?team=Ankaragucu">Ankaragucu</a>
# 13      <a href="team.php?team=Kasimpasa">Kasimpasa</a>
# 14          <a href="team.php?team=Goztepe">Goztepe</a>
# 15      <a href="team.php?team=Bursaspor">Bursaspor</a>
# 16    <a href="team.php?team=Erzurum+Buyuksehir+Bele...
# 17    <a href="team.php?team=Akhisar+Belediye">Akhis...
# Name: Team, dtype: object

# %%
for i in range(0,len(df_team)):
    print(df_team[i])
# Out:
# <a href="team.php?team=Galatasaray">Galatasaray</a>
# <a href="team.php?team=Istanbul+Basaksehir">Istanbul Basaksehir</a>
# <a href="team.php?team=Besiktas">Besiktas</a>
# <a href="team.php?team=Trabzonspor">Trabzonspor</a>
# <a href="team.php?team=Yeni+Malatyaspor">Yeni Malatyaspor</a>
# <a href="team.php?team=Fenerbahce">Fenerbahce</a>
# <a href="team.php?team=Antalyaspor">Antalyaspor</a>
# <a href="team.php?team=Konyaspor">Konyaspor</a>
# <a href="team.php?team=Alanyaspor">Alanyaspor</a>
# <a href="team.php?team=Caykur+Rizespor">Caykur Rizespor</a>
# <a href="team.php?team=Sivasspor">Sivasspor</a>
# <a href="team.php?team=Kayserispor">Kayserispor</a>
# <a href="team.php?team=Ankaragucu">Ankaragucu</a>
# <a href="team.php?team=Kasimpasa">Kasimpasa</a>
# <a href="team.php?team=Goztepe">Goztepe</a>
# <a href="team.php?team=Bursaspor">Bursaspor</a>
# <a href="team.php?team=Erzurum+Buyuksehir+Belediyespor">Erzurum Buyuksehir Belediyespor</a>
# <a href="team.php?team=Akhisar+Belediye">Akhisar Belediye</a>

# %%
df['Team'] = df_team

# %%
df
# Out:
#    Pos                                               Team   P   W   D   L   F  \
# 0    1  <a href="team.php?team=Galatasaray">Galatasara...  34  20   9   5  72
# 1    2  <a href="team.php?team=Istanbul+Basaksehir">Is...  34  19  10   5  49
# 2    3      <a href="team.php?team=Besiktas">Besiktas</a>  34  19   8   7  72
# 3    4  <a href="team.php?team=Trabzonspor">Trabzonspo...  34  18   9   7  64
# 4    5  <a href="team.php?team=Yeni+Malatyaspor">Yeni ...  34  13   8  13  47
# 5    6  <a href="team.php?team=Fenerbahce">Fenerbahce</a>  34  11  13  10  44
# 6    7  <a href="team.php?team=Antalyaspor">Antalyaspo...  34  13   6  15  39
# 7    8    <a href="team.php?team=Konyaspor">Konyaspor</a>  34   9  17   8  40
# 8    9  <a href="team.php?team=Alanyaspor">Alanyaspor</a>  34  12   8  14  37
# 9   10  <a href="team.php?team=Caykur+Rizespor">Caykur...  34   9  14  11  48
# 10  11    <a href="team.php?team=Sivasspor">Sivasspor</a>  34  10  11  13  49
# 11  12  <a href="team.php?team=Kayserispor">Kayserispo...  34  10  11  13  35
# 12  13  <a href="team.php?team=Ankaragucu">Ankaragucu</a>  34  11   7  16  38
# 13  14    <a href="team.php?team=Kasimpasa">Kasimpasa</a>  34  11   6  17  53
# 14  15        <a href="team.php?team=Goztepe">Goztepe</a>  34  11   5  18  37
# 15  16    <a href="team.php?team=Bursaspor">Bursaspor</a>  34   7  16  11  28
# 16  17  <a href="team.php?team=Erzurum+Buyuksehir+Bele...  34   8  11  15  36
# 17  18  <a href="team.php?team=Akhisar+Belediye">Akhis...  34   6   9  19  33
#
#      A   GD Pts
# 0   36  +36  69
# 1   22  +27  67
# 2   46  +26  65
# 3   46  +18  63
# 4   46   +1  47
# 5   44   +0  46
# 6   55  -16  45
# 7   38   +2  44
# 8   43   -6  44
# 9   50   -2  41
# 10  54   -5  41
# 11  50  -15  41
# 12  53  -15  40
# 13  62   -9  39
# 14  42   -5  38
# 15  37   -9  37
# 16  43   -7  35
# 17  54  -21  27
