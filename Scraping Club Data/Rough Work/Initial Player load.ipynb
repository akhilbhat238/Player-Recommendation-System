# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
player_df = pd.read_csv('..\\Consolidated Data\\players_20.csv')

# %%
player_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...    lwb   ldm  \
# ...

# %%
player_df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
for i in range(0,len(player_df.columns)):
    print(player_df.columns[i])
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
messi = player_df.iloc[0]

# %%
for i in range(0,len(messi)):
    print(messi[i])
# Out:
# 158023
# https://sofifa.com/player/158023/lionel-messi/20/159586
# L. Messi
# Lionel Andrés Messi Cuccittini
# 32
# 1987-06-24
# 170
# 72
# Argentina
# FC Barcelona
# 94
# 94
# 95500000
# 565000
# RW, CF, ST
# Left
# 5
# 4
# 4
# Medium/Low
# Messi
# Yes
# 195800000.0
# #Dribbler, #Distance Shooter, #Crosser, #FK Specialist, #Acrobat, #Clinical Finisher, #Complete Forward
# RW
# 10.0
# nan
# 2004-07-01
# 2021.0
# nan
# nan
# 87.0
# 92.0
# 92.0
# 96.0
# 39.0
# 66.0
# nan
# nan
# nan
# nan
# nan
# nan
# Beat Offside Trap, Argues with Officials, Early Crosser, Finesse Shot, Speed Dribbler (CPU AI Only), 1-on-1 Rush, Giant Throw-in, Outside Foot Shot
# 88
# 95
# 70
# 92
# 88
# 97
# 93
# 94
# 92
# 96
# 91
# 84
# 93
# 95
# 95
# 86
# 68
# 75
# 68
# 94
# 48
# 40
# 94
# 94
# 75
# 96
# 33
# 37
# 26
# 6
# 11
# 15
# 14
# 8
# 89+2
# 89+2
# 89+2
# 93+2
# 93+2
# 93+2
# 93+2
# 93+2
# 93+2
# 93+2
# 93+2
# 92+2
# 87+2
# 87+2
# 87+2
# 92+2
# 68+2
# 66+2
# 66+2
# 66+2
# 68+2
# 63+2
# 52+2
# 52+2
# 52+2
# ...

# %%
messi.pace
# Out:
# 87.0

# %%
rel_cols = ['sofifa_id',
'player_url',
'short_name',
'long_name',
'age',
'nationality',
'club',
'overall',
'value_eur',
'wage_eur',
'preferred_foot',
'release_clause_eur',
'team_position',
'contract_valid_until',
'pace',
'shooting',
'passing',
'dribbling',
'defending',
'gk_diving',
'gk_handling',
'gk_kicking',
'gk_reflexes',
'gk_speed',
'gk_positioning',
'attacking_crossing',
'attacking_finishing',
'attacking_heading_accuracy',
'attacking_short_passing',
'attacking_volleys',
'skill_dribbling',
'skill_curve',
'skill_fk_accuracy',
'skill_long_passing',
'skill_ball_control',
'movement_acceleration',
'movement_sprint_speed',
'movement_agility',
'movement_reactions',
'movement_balance',
'power_shot_power',
'power_jumping',
'power_stamina',
'power_strength',
'power_long_shots',
'mentality_aggression',
'mentality_interceptions',
'mentality_positioning',
'mentality_vision',
'mentality_penalties',
'mentality_composure',
'defending_marking',
'defending_standing_tackle',
'defending_sliding_tackle',
'goalkeeping_diving',
'goalkeeping_handling',
'goalkeeping_kicking',
'goalkeeping_positioning',
'goalkeeping_reflexes']

# %%
updated_df = player_df[rel_cols]

# %%
updated_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age nationality  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32   Argentina
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34    Portugal
# 2          Neymar Jr        Neymar da Silva Santos Junior   27      Brazil
# 3           J. Oblak                            Jan Oblak   26    Slovenia
# 4          E. Hazard                          Eden Hazard   28     Belgium
#
#                   club  overall  value_eur  wage_eur          ...           \
# ...

# %%
attribute_cols = ['overall',
'pace',
'shooting',
'passing',
'dribbling',
'defending',
'gk_diving',
'gk_handling',
'gk_kicking',
'gk_reflexes',
'gk_speed',
'gk_positioning',
'attacking_crossing',
'attacking_finishing',
'attacking_heading_accuracy',
'attacking_short_passing',
'attacking_volleys',
'skill_dribbling',
'skill_curve',
'skill_fk_accuracy',
'skill_long_passing',
'skill_ball_control',
'movement_acceleration',
'movement_sprint_speed',
'movement_agility',
'movement_reactions',
'movement_balance',
'power_shot_power',
'power_jumping',
'power_stamina',
'power_strength',
'power_long_shots',
'mentality_aggression',
'mentality_interceptions',
'mentality_positioning',
'mentality_vision',
'mentality_penalties',
'mentality_composure',
'defending_marking',
'defending_standing_tackle',
'defending_sliding_tackle',
'goalkeeping_diving',
'goalkeeping_handling',
'goalkeeping_kicking',
'goalkeeping_positioning',
'goalkeeping_reflexes']

# %%
attr_df = updated_df[attribute_cols]

# %%
attr_df.head()
# Out:
#    overall  pace  shooting  passing  dribbling  defending  gk_diving  \
# 0       94  87.0      92.0     92.0       96.0       39.0        NaN
# 1       93  90.0      93.0     82.0       89.0       35.0        NaN
# 2       92  91.0      85.0     87.0       95.0       32.0        NaN
# 3       91   NaN       NaN      NaN        NaN        NaN       87.0
# 4       91  91.0      83.0     86.0       94.0       35.0        NaN
#
#    gk_handling  gk_kicking  gk_reflexes          ...           \
# 0          NaN         NaN          NaN          ...
# 1          NaN         NaN          NaN          ...
# 2          NaN         NaN          NaN          ...
# 3         92.0        78.0         89.0          ...
# 4          NaN         NaN          NaN          ...
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# ...

# %%
oblak = player_df.iloc[3]

# %%
oblak[attribute_cols]
# Out:
# overall                        91
# pace                          NaN
# shooting                      NaN
# passing                       NaN
# dribbling                     NaN
# defending                     NaN
# gk_diving                      87
# gk_handling                    92
# gk_kicking                     78
# gk_reflexes                    89
# gk_speed                       52
# gk_positioning                 90
# attacking_crossing             13
# attacking_finishing            11
# attacking_heading_accuracy     15
# attacking_short_passing        43
# attacking_volleys              13
# skill_dribbling                12
# skill_curve                    13
# skill_fk_accuracy              14
# skill_long_passing             40
# skill_ball_control             30
# movement_acceleration          43
# movement_sprint_speed          60
# movement_agility               67
# movement_reactions             88
# movement_balance               49
# ...

# %%
gk_attr = ['overall',
'gk_diving',
'gk_handling',
'gk_kicking',
'gk_reflexes',
'gk_speed',
'gk_positioning',
'mentality_aggression',
'mentality_interceptions',
'mentality_positioning',
'mentality_vision',
'mentality_penalties',
'mentality_composure',
'goalkeeping_diving',
'goalkeeping_handling',
'goalkeeping_kicking',
'goalkeeping_positioning',
'goalkeeping_reflexes']

# %%
gk_df = attr_df[gk_attr]

# %%
gk_df=gk_df.dropna()

# %%
gk_df
# Out:
#        overall  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 3           91       87.0         92.0        78.0         89.0      52.0
# 6           90       88.0         85.0        88.0         90.0      45.0
# 13          89       85.0         84.0        85.0         89.0      51.0
# 14          89       90.0         84.0        81.0         92.0      58.0
# 25          88       86.0         82.0        93.0         88.0      63.0
# 28          88       85.0         89.0        72.0         87.0      49.0
# 30          88       88.0         85.0        69.0         89.0      53.0
# 31          88       87.0         87.0        91.0         87.0      57.0
# 32          88       89.0         82.0        68.0         91.0      63.0
# 53          87       90.0         81.0        75.0         90.0      53.0
# 60          86       85.0         82.0        73.0         88.0      49.0
# 74          85       90.0         80.0        74.0         90.0      50.0
# ...

# %%
gk_corrMatrix = gk_df.corr()

# %%
print (gk_corrMatrix)
# Out:
#                           overall  gk_diving  gk_handling  gk_kicking  \
# overall                  1.000000   0.948912     0.925025    0.790903
# gk_diving                0.948912   1.000000     0.840950    0.731431
# gk_handling              0.925025   0.840950     1.000000    0.736218
# gk_kicking               0.790903   0.731431     0.736218    1.000000
# gk_reflexes              0.947823   0.916992     0.829646    0.725041
# gk_speed                 0.480652   0.459595     0.397455    0.381067
# gk_positioning           0.944758   0.854291     0.876197    0.736911
# mentality_aggression     0.304142   0.260611     0.264852    0.265837
# mentality_interceptions  0.413691   0.375033     0.353379    0.319920
# mentality_positioning    0.390037   0.355922     0.326409    0.324448
# mentality_vision         0.405370   0.356558     0.381362    0.404894
# mentality_penalties      0.320342   0.309603     0.267646    0.261239
# ...

# %%
import seaborn as sn
plt.figure(figsize=(16, 6))
sn.heatmap(gk_corrMatrix, annot=True)

# %%
gk_df.head()
# Out:
#     overall  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 3        91       87.0         92.0        78.0         89.0      52.0
# 6        90       88.0         85.0        88.0         90.0      45.0
# 13       89       85.0         84.0        85.0         89.0      51.0
# 14       89       90.0         84.0        81.0         92.0      58.0
# 25       88       86.0         82.0        93.0         88.0      63.0
#
#     gk_positioning  mentality_aggression  mentality_interceptions  \
# 3             90.0                    34                       19
# 6             88.0                    43                       22
# 13            90.0                    27                       11
# 14            85.0                    38                       30
# 25            86.0                    38                       27
#
#     mentality_positioning  mentality_vision  mentality_penalties  \
# 3                      11                65                   11
# ...

# %%
gk_relevant_attr = ['overall','gk_diving','gk_handling','gk_reflexes','gk_positioning']

# %%
gk_df=gk_df[gk_relevant_attr]

# %%
main_attr = ['sofifa_id',
'player_url',
'short_name',
'long_name',
'age',
'dob',
'height_cm',
'nationality',
'club',
'value_eur',
'wage_eur',
'player_positions',
'preferred_foot',
'release_clause_eur',
'team_position',
'contract_valid_until']

# %%
player_df[main_attr].head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm nationality                 club  value_eur  wage_eur  \
# ...

# %%
final_gk_df = player_df[main_attr].join(gk_df,how='inner')

# %%
final_gk_df.head()
# Out:
#     sofifa_id                                         player_url  \
# 3      200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
# 14     193080  https://sofifa.com/player/193080/david-de-gea-...
# 25     210257  https://sofifa.com/player/210257/ederson-santa...
#
#        short_name                  long_name  age         dob  height_cm  \
# 3        J. Oblak                  Jan Oblak   26  1993-01-07        188
# 6   M. ter Stegen      Marc-André ter Stegen   27  1992-04-30        187
# 13        Alisson      Alisson Ramses Becker   26  1992-10-02        191
# 14         De Gea      David De Gea Quintana   28  1990-11-07        192
# 25        Ederson  Ederson Santana de Moraes   25  1993-08-17        188
#
#    nationality               club  value_eur       ...        \
# 3     Slovenia    Atlético Madrid   77500000       ...
# ...

# %%
player_df['team_position'].unique()
# Out:
# array(['RW', 'LW', 'CAM', 'GK', 'RCM', 'LCB', 'ST', 'CDM', 'LDM', 'RM',
#        'RCB', 'LCM', 'LM', 'CF', 'SUB', 'LB', 'LS', 'RB', 'RDM', 'RES',
#        'RAM', 'RS', 'RF', 'CM', 'CB', 'LF', 'LAM', nan, 'RWB', 'LWB'],
#       dtype=object)

# %%
player_df['team_position']=player_df['team_position'].fillna('Unkown')

# %%
player_df['team_position'].unique()
# Out:
# array(['RW', 'LW', 'CAM', 'GK', 'RCM', 'LCB', 'ST', 'CDM', 'LDM', 'RM',
#        'RCB', 'LCM', 'LM', 'CF', 'SUB', 'LB', 'LS', 'RB', 'RDM', 'RES',
#        'RAM', 'RS', 'RF', 'CM', 'CB', 'LF', 'LAM', 'Unkown', 'RWB', 'LWB'],
#       dtype=object)

# %%
player_df[player_df['team_position'].isin(['RW','LW','CF','LS','ST'])].head()
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...
# 10     231747  https://sofifa.com/player/231747/kylian-mbappe...
#
#            short_name                            long_name  age         dob  \
# 0            L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 4           E. Hazard                          Eden Hazard   28  1991-01-07
# 9            M. Salah                 Mohamed  Salah Ghaly   27  1992-06-15
# 10          K. Mbappé                        Kylian Mbappé   20  1998-12-20
#
#     height_cm  weight_kg nationality                 club  ...    lwb   ldm  \
# ...

# %%
player_df['nation_position'].unique()
# Out:
# array([nan, 'LS', 'LW', 'GK', 'LF', 'RCM', 'SUB', 'LCB', 'RW', 'RM', 'ST',
#        'LDM', 'RCB', 'CDM', 'CAM', 'CF', 'RDM', 'RF', 'LB', 'LCM', 'LM',
#        'RB', 'CB', 'CM', 'RS', 'RWB', 'LWB'], dtype=object)

# %%
player_df['nation_position']=player_df['nation_position'].fillna('Unkown')

# %%
player_df['nation_position'].unique()
# Out:
# array(['Unkown', 'LS', 'LW', 'GK', 'LF', 'RCM', 'SUB', 'LCB', 'RW', 'RM',
#        'ST', 'LDM', 'RCB', 'CDM', 'CAM', 'CF', 'RDM', 'RF', 'LB', 'LCM',
#        'LM', 'RB', 'CB', 'CM', 'RS', 'RWB', 'LWB'], dtype=object)

# %%
player_df[player_df['team_position']=='SUB'].head()
# Out:
#     sofifa_id                                         player_url  short_name  \
# 48     175943  https://sofifa.com/player/175943/dries-mertens...  D. Mertens
# 53     193041  https://sofifa.com/player/193041/keylor-navas/...    K. Navas
# 55     222492  https://sofifa.com/player/222492/leroy-sane/20...     L. Sané
# 59     205600  https://sofifa.com/player/205600/samuel-umtiti...   S. Umtiti
# 62     197781  https://sofifa.com/player/197781/francisco-rom...        Isco
#
#                          long_name  age         dob  height_cm  weight_kg  \
# 48                   Dries Mertens   32  1987-05-06        169         61
# 53                    Keylor Navas   32  1986-12-15        185         80
# 55                      Leroy Sané   23  1996-01-11        183         75
# 59                   Samuel Umtiti   25  1993-11-14        182         75
# 62  Francisco Román Alarcón Suárez   27  1992-04-21        176         79
#
# ...

# %%
player_df[player_df['team_position']=='SUB']
# Out:
#        sofifa_id                                         player_url  \
# 48        175943  https://sofifa.com/player/175943/dries-mertens...
# 53        193041  https://sofifa.com/player/193041/keylor-navas/...
# 55        222492  https://sofifa.com/player/222492/leroy-sane/20...
# 59        205600  https://sofifa.com/player/205600/samuel-umtiti...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 70        189596  https://sofifa.com/player/189596/thomas-muller...
# 73        235243  https://sofifa.com/player/235243/matthijs-de-l...
# 79        231866  https://sofifa.com/player/231866/rodrigo-herna...
# 91        194404  https://sofifa.com/player/194404/norberto-mura...
# 98        167664  https://sofifa.com/player/167664/gonzalo-higua...
# 99        170890  https://sofifa.com/player/170890/blaise-matuid...
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106       198710  https://sofifa.com/player/198710/james-rodrigu...
# ...

# %%
player_df[player_df['team_position']=='SUB']['nation_position'].unique()
# Out:
# array(['RF', 'Unkown', 'LW', 'LCB', 'RCB', 'SUB', 'LM', 'RM', 'CAM',
#        'RCM', 'LCM', 'RW', 'ST', 'RS', 'LB', 'GK', 'RB', 'CDM', 'LDM',
#        'LS'], dtype=object)

# %%
player_df[player_df['team_position']=='SUB']
# Out:
#        sofifa_id                                         player_url  \
# 48        175943  https://sofifa.com/player/175943/dries-mertens...
# 53        193041  https://sofifa.com/player/193041/keylor-navas/...
# 55        222492  https://sofifa.com/player/222492/leroy-sane/20...
# 59        205600  https://sofifa.com/player/205600/samuel-umtiti...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 70        189596  https://sofifa.com/player/189596/thomas-muller...
# 73        235243  https://sofifa.com/player/235243/matthijs-de-l...
# 79        231866  https://sofifa.com/player/231866/rodrigo-herna...
# 91        194404  https://sofifa.com/player/194404/norberto-mura...
# 98        167664  https://sofifa.com/player/167664/gonzalo-higua...
# 99        170890  https://sofifa.com/player/170890/blaise-matuid...
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106       198710  https://sofifa.com/player/198710/james-rodrigu...
# ...

# %%
player_df[player_df['nation_position']=='SUB']
# Out:
#        sofifa_id                                         player_url  \
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 79        231866  https://sofifa.com/player/231866/rodrigo-herna...
# 104       192629  https://sofifa.com/player/192629/iago-aspas-ju...
# 105       193747  https://sofifa.com/player/193747/jorge-resurre...
# 109       235790  https://sofifa.com/player/235790/kai-havertz/2...
# 110       231443  https://sofifa.com/player/231443/ousmane-dembe...
# 111       206585  https://sofifa.com/player/206585/kepa-arrizaba...
# 112       210514  https://sofifa.com/player/210514/joao-pedro-ca...
# 118       212194  https://sofifa.com/player/212194/julian-brandt...
# 119       213345  https://sofifa.com/player/213345/kingsley-coma...
# 125       236583  https://sofifa.com/player/236583/jiri-pavlenka...
# 126       198176  https://sofifa.com/player/198176/stefan-de-vri...
# ...

# %%
player_df['nation_position']=player_df['nation_position'].fillna('Unkown')

# %%
if player_df.iloc[53]['lwb'] is None:
    print('x')
else:
    print('y')
# Out:
# y

# %%
player_df = pd.read_csv('..\\Consolidated Data\\players_20.csv')

# %%
for i in range(0,len(player_df.columns)):
    print(player_df.columns[i])
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
player_pos_df = player_df[['sofifa_id','short_name','player_positions','team_position','nation_position']]

# %%
player_pos_df['player_positions'] = player_pos_df['player_positions'].fillna('Unknown')
# Out:
# c:\users\akhil_s_bhat\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
player_pos_df['team_position'] = player_pos_df['team_position'].fillna('Unknown')
# Out:
# c:\users\akhil_s_bhat\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
player_pos_df['nation_position'] = player_pos_df['nation_position'].fillna('Unknown')
# Out:
# c:\users\akhil_s_bhat\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
player_pos_df.head()
# Out:
#    sofifa_id         short_name player_positions team_position nation_position
# 0     158023           L. Messi       RW, CF, ST            RW         Unknown
# 1      20801  Cristiano Ronaldo           ST, LW            LW              LS
# 2     190871          Neymar Jr          LW, CAM           CAM              LW
# 3     200389           J. Oblak               GK            GK              GK
# 4     183277          E. Hazard           LW, CF            LW              LF

# %%
player_pos_df[player_pos_df['team_position']=='Unknown']
# Out:
#        sofifa_id      short_name player_positions team_position  \
# 327       245309     E. Schetino               CB       Unknown
# 328       245313      J. Sildero          CAM, RM       Unknown
# 407       245299     J. Frendado          CB, CDM       Unknown
# 408       245304       S. Ardero      CAM, LM, LW       Unknown
# 409       245305       L. Dálves           ST, CF       Unknown
# 410       251700    S. Mandíquez               ST       Unknown
# 565       245294    J. Serendero               GK       Unknown
# 566       245300      M. Baldona          CDM, CM       Unknown
# 567       245308        M. Nérez           LB, LM       Unknown
# 648       229909        A. Lunev               GK       Unknown
# 749       245298      D. Lenzado           CB, LB       Unknown
# 750       245302      E. Riquero     CDM, CM, CAM       Unknown
# 751       245306       L. Sáreda               GK       Unknown
# 752       245315      E. Aguerro               ST       Unknown
# ...

# %%
player_pos_df[player_pos_df['team_position']=='SUB'].head()
# Out:
#     sofifa_id  short_name player_positions team_position nation_position
# 48     175943  D. Mertens           CF, ST           SUB              RF
# 53     193041    K. Navas               GK           SUB         Unknown
# 55     222492     L. Sané               LW           SUB              LW
# 59     205600   S. Umtiti               CB           SUB             LCB
# 62     197781        Isco      CAM, CM, LW           SUB              LW

# %%
player_pos_df['team_position'].unique()
# Out:
# array(['RW', 'LW', 'CAM', 'GK', 'RCM', 'LCB', 'ST', 'CDM', 'LDM', 'RM',
#        'RCB', 'LCM', 'LM', 'CF', 'SUB', 'LB', 'LS', 'RB', 'RDM', 'RES',
#        'RAM', 'RS', 'RF', 'CM', 'CB', 'LF', 'LAM', 'Unknown', 'RWB',
#        'LWB'], dtype=object)

# %%
def pos_func(row):
    if (player_pos_df.iloc[row]['team_position'] == 'Unknown'):
        if (player_pos_df.iloc[row]['nation_position'] == 'Unknown'):
            return(player_pos_df.iloc[row]['player_positions'])
        else:            
            return(player_pos_df.iloc[row]['player_positions'])
    elif (player_pos_df.iloc[row]['team_position'] == 'SUB'):
        if (player_pos_df.iloc[row]['nation_position'] == 'Unknown'):
            return(player_pos_df.iloc[row]['player_positions'])
        elif(player_pos_df.iloc[row]['nation_position'] == 'SUB'):
            return(player_pos_df.iloc[row]['player_positions'])
        else:
            return(player_pos_df.iloc[row]['nation_position'])    
    elif (player_pos_df.iloc[row]['team_position'] == 'RES'):
        if (player_pos_df.iloc[row]['nation_position'] == 'Unknown'):
            return(player_pos_df.iloc[row]['player_positions'])
        elif(player_pos_df.iloc[row]['nation_position'] == 'SUB'):
            return(player_pos_df.iloc[row]['player_positions'])
        else:
            return(player_pos_df.iloc[row]['nation_position'])
    else:
        return(player_pos_df.iloc[row]['team_position'])

# %%
player_pos_df.head()
# Out:
#    sofifa_id         short_name player_positions team_position nation_position
# 0     158023           L. Messi       RW, CF, ST            RW         Unknown
# 1      20801  Cristiano Ronaldo           ST, LW            LW              LS
# 2     190871          Neymar Jr          LW, CAM           CAM              LW
# 3     200389           J. Oblak               GK            GK              GK
# 4     183277          E. Hazard           LW, CF            LW              LF

# %%
entries = []
for i in range(0,len(player_pos_df)):
#     print((pos_func(i)))
#     player_pos_df.iloc[i]['Final_Pos'] = pos_func(i)
#     print(pos_func(i))
    entries.append(pos_func(i))

# %%
entries
# Out:
# ['RW',
#  'LW',
#  'CAM',
#  'GK',
#  'LW',
#  'RCM',
#  'GK',
#  'LCB',
#  'RCM',
#  'RW',
#  'RW',
#  'LCB',
#  'ST',
#  'GK',
#  'GK',
#  'RCM',
#  'LCB',
#  'ST',
#  'LCB',
#  'ST',
#  'ST',
#  'CDM',
#  'LW',
#  'RW',
#  'LDM',
#  'GK',
#  'LW',
#  'RM',
#  'GK',
#  'RCB',
#  'GK',
#  'GK',
#  'GK',
#  'LCM',
#  'ST',
#  'RCB',
#  'LCM',
#  'CAM',
#  'LM',
#  'LW',
#  'LCB',
#  'RW',
#  'CDM',
#  'LM',
#  'CDM',
#  'LCB',
#  'CF',
#  'LCB',
#  'RF',
#  'LCB',
#  'RCB',
#  'LB',
#  'CDM',
#  'GK',
#  'LS',
#  'LW',
#  'RCB',
#  'LCB',
#  'RCM',
#  'LCB',
#  'GK',
#  'RB',
#  'LW',
#  'CF',
#  'RCM',
#  'CDM',
#  'LW',
#  'RCB',
#  'LCM',
#  'RCM',
#  'CAM, RM, RW',
#  'ST',
#  'ST',
#  'RCB',
#  'GK',
#  'LCM',
#  'RCB',
#  'RCB',
#  'RDM',
#  'SUB',
#  'LCM',
#  'CDM',
#  'LB',
#  'RCB',
#  'LCB',
#  'RCM',
#  'GK',
#  'GK',
#  'GK',
#  'LS',
#  'RCB',
#  'GK',
#  'LB',
#  'ST',
#  'RB',
#  'RAM',
#  'ST',
#  'CAM',
#  'ST',
#  'LM',
#  'RM',
#  'LB',
#  'LDM',
#  'LB',
# ...

# %%
player_pos_df['final_position'] = entries
# Out:
# c:\users\akhil_s_bhat\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
player_pos_df['final_position'].unique()
# Out:
# array(['RW', 'LW', 'CAM', 'GK', 'RCM', 'LCB', 'ST', 'CDM', 'LDM', 'RM',
#        'RCB', 'LCM', 'LM', 'CF', 'RF', 'LB', 'LS', 'RB', 'CAM, RM, RW',
#        'RDM', 'SUB', 'RAM', 'RS', 'CM', 'CB', 'CDM, CB', 'LM, RW, LW',
#        'RW, RM', 'CAM, CM, RM', 'CF, RM, LM', 'CM, CDM', 'RM, ST', 'LF',
#        'CF, CAM, CM', 'CB, LB, RB', 'CAM, RM', 'RW, LW', 'LAM', 'CM, LW',
#        'CB, RB', 'CAM, CM, LM', 'CAM, CM, RW', 'CAM, CM', 'CM, LB',
#        'CDM, CM', 'LB, LWB', 'RM, CAM, RW', 'CB, CDM', 'CAM, LM, LW',
#        'ST, CF', 'RB, RWB', 'RM, ST, LM', 'CM, RM', 'CAM, CF',
#        'RM, LM, CM', 'RWB', 'CF, ST, RM', 'ST, LM', 'LWB', 'LW, CF, ST',
#        'LM, RW', 'RM, RW, LM', 'LM, RM', 'LB, LM', 'RW, LW, ST',
#        'RW, ST, LW', 'LB, RB', 'CB, LB', 'LB, LM, LWB', 'RM, CAM, CM',
#        'LM, LW, RM', 'LM, CF', 'CM, CAM, CDM', 'ST, CAM', 'CAM, CDM',
#        'CF, CM', 'CM, LM, RM', 'CM, LW, RW', 'RB, RM, CB', 'RM, RW',
# ...

# %%
player_pos_df.head()
# Out:
#    sofifa_id         short_name player_positions team_position  \
# 0     158023           L. Messi       RW, CF, ST            RW
# 1      20801  Cristiano Ronaldo           ST, LW            LW
# 2     190871          Neymar Jr          LW, CAM           CAM
# 3     200389           J. Oblak               GK            GK
# 4     183277          E. Hazard           LW, CF            LW
#
#   nation_position final_position
# 0         Unknown             RW
# 1              LS             LW
# 2              LW            CAM
# 3              GK             GK
# 4              LF             LW

# %%
player_pos_df[player_pos_df['sofifa_id']==248360].final_position
# Out:
# 18248    LW, LM
# Name: final_position, dtype: object

# %%
x = 'LW, LM'

# %%
x.find(',')
# Out:
# 2

# %%
x[:x.find(',')]
# Out:
# 'LW'

# %%
x = 'RW, CF, ST'

# %%
x[:x.find(',')]
# Out:
# 'RW'

# %%
player_pos_df['final_position'] = player

# %%
entries = []
for i in range(0,len(player_pos_df)):
    x=player_pos_df.iloc[i]['player_positions']
    if(x.find(',')==-1):
        entries.append(x)
    else:
        entries.append(x[:x.find(',')])

# %%
player_pos_df['final_position'] = entries
# Out:
# c:\users\akhil_s_bhat\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
player_pos_df.head()
# Out:
#    sofifa_id         short_name player_positions team_position  \
# 0     158023           L. Messi       RW, CF, ST            RW
# 1      20801  Cristiano Ronaldo           ST, LW            LW
# 2     190871          Neymar Jr          LW, CAM           CAM
# 3     200389           J. Oblak               GK            GK
# 4     183277          E. Hazard           LW, CF            LW
#
#   nation_position final_position
# 0         Unknown             RW
# 1              LS             ST
# 2              LW             LW
# 3              GK             GK
# 4              LF             LW

# %%
player_pos_df['final_position'].unique()
# Out:
# array(['RW', 'ST', 'LW', 'GK', 'CAM', 'CB', 'CM', 'CDM', 'CF', 'LB', 'RB',
#        'RM', 'LM', 'LWB', 'RWB'], dtype=object)

# %%
player_pos_df=player_pos_df.drop(['player_positions','team_position','nation_position'],axis=1)
# data = data.drop("Area", axis=1)

# %%
player_pos_df.head()
# Out:
#    sofifa_id         short_name final_position
# 0     158023           L. Messi             RW
# 1      20801  Cristiano Ronaldo             ST
# 2     190871          Neymar Jr             LW
# 3     200389           J. Oblak             GK
# 4     183277          E. Hazard             LW

# %%
player_df = player_df.join(player_pos_df['final_position'],how='inner')

# %%
player_df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club      ...         ldm  \
# ...
