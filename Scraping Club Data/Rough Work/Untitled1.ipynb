# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.transfermarkt.co.uk/manchester-city/kader/verein/281/saison_id/2019'
headers = {"User-Agent":"Mozilla/5.0"}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
tables = soup.findAll("table")

# %%
data_values = tables[1].find('tbody').find_all('tr')

# %%
print(data_values[6].find_all('td')[3].contents[0].contents[0].contents[0].contents[0])
# Out:
# Scott Carson

# %%
for i in range(0,len(data_values),3):
#     print(i)
    if(data_values[i].find_all('td')[1].contents[0].name=='table'):
        print(i)
        print(data_values[i].find_all('td')[0].get('title'))
        print(data_values[i].find_all('td')[1].contents[0].contents[0].find_all('a')[1].contents[0])
        print(data_values[i].find_all('td')[5].contents[0])
        print(data_values[i].find_all('td')[6].contents[0].get('title'))
        print(data_values[i].find_all('td')[7].contents[0])
        print(data_values[i].find_all('td')[8].contents[0].strip())
    else:
        print(i)
        print(data_values[i].find_all('td')[0].get('title'))
        print(data_values[i].find_all('td')[3].contents[0].contents[0].contents[0].contents[0])
        print(data_values[i].find_all('td')[5].contents[0])
        print(data_values[i].find_all('td')[6].contents[0].get('title'))
        print(data_values[i].find_all('td')[7].contents[0])
        print(data_values[i].find_all('td')[8].contents[0].strip())
# Out:
# 0
# Goalkeeper
# Ederson
# Aug 17, 1993 (26)
# Brazil
# 30.06.2025
# £63.00m
# 3
# Goalkeeper
# Claudio Bravo
# Apr 13, 1983 (36)
# Chile
# 30.06.2020
# £2.25m
# 6
# Goalkeeper
# Scott Carson
# Sep 3, 1985 (34)
# England
# 31.05.2020
# £1.80m
# 9
# Defender
# Aymeric Laporte
# May 27, 1994 (25)
# France
# 30.06.2025
# £67.50m
# 12
# Defender
# John Stones
# May 28, 1994 (25)
# England
# 30.06.2022
# £54.00m
# 15
# Defender
# Nicolás Otamendi
# Feb 12, 1988 (31)
# Argentina
# 30.06.2022
# £22.50m
# 18
# Defender
# Benjamin Mendy
# Jul 17, 1994 (25)
# France
# 30.06.2023
# £31.50m
# 21
# Defender
# Oleksandr Zinchenko
# Dec 15, 1996 (22)
# Ukraine
# 30.06.2024
# £27.00m
# 24
# Defender
# Angeliño
# Jan 4, 1997 (22)
# Spain
# 30.06.2023
# £14.40m
# 27
# Defender
# João Cancelo
# May 27, 1994 (25)
# Portugal
# 30.06.2025
# £49.50m
# 30
# Defender
# Kyle Walker
# May 28, 1990 (29)
# England
# 30.06.2024
# £45.00m
# 33
# Midfielder
# Rodri
# Jun 22, 1996 (23)
# Spain
# 30.06.2024
# £72.00m
# 36
# Midfielder
# Fernandinho
# May 4, 1985 (34)
# Brazil
# 30.06.2020
# £10.80m
# 39
# Midfielder
# Ilkay Gündogan
# Oct 24, 1990 (28)
# Germany
# 30.06.2023
# £45.00m
# 42
# Midfielder
# Phil Foden
# May 28, 2000 (19)
# England
# 30.06.2024
# £27.00m
# 45
# Midfielder
# Kevin De Bruyne
# Jun 28, 1991 (28)
# Belgium
# 30.06.2023
# £117.00m
# 48
# Midfielder
# David Silva
# Jan 8, 1986 (33)
# Spain
# 30.06.2020
# £18.00m
# 51
# Forward
# Raheem Sterling
# Dec 8, 1994 (24)
# England
# 30.06.2023
# £126.00m
# 54
# Forward
# Leroy Sané
# Jan 11, 1996 (23)
# Germany
# 30.06.2021
# £90.00m
# 57
# Forward
# Bernardo Silva
# Aug 10, 1994 (25)
# Portugal
# 30.06.2025
# £90.00m
# 60
# Forward
# Riyad Mahrez
# Feb 21, 1991 (28)
# Algeria
# 30.06.2023
# £54.00m
# 63
# Forward
# Gabriel Jesus
# Apr 3, 1997 (22)
# Brazil
# 30.06.2023
# £63.00m
# 66
# Forward
# Sergio Agüero
# Jun 2, 1988 (31)
# Argentina
# 30.06.2021
# £58.50m

# %%
url = 'https://www.transfermarkt.co.uk/fc-liverpool/kader/verein/31/saison_id/2019'
headers = {"User-Agent":"Mozilla/5.0"}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
tables = soup.findAll("table")
data_values = tables[1].find('tbody').find_all('tr')

# %%
i=0

# %%
data_values[i].find_all('td')
# Out:
# [<td class="zentriert rueckennummer bg_Torwart" title="Goalkeeper"><div class="rn_nummer">1</div></td>,
#  <td class="posrela" title=""><table class="inline-table" title=""><tr><td class="" rowspan="2"><a href="#"><img alt="Alisson" class="bilderrahmen-fixed" src="https://tmssl.akamaized.net//images/portrait/small/105470-1447747290.jpg?lm=1447747302" title="Alisson"/></a></td><td class="hauptlink"><div class="di nowrap"><span class="hide-for-small"><a class="spielprofil_tooltip" href="/alisson/profil/spieler/105470" id="105470" title="Alisson">Alisson</a></span></div><div class="di nowrap"><span class="show-for-small"><a class="spielprofil_tooltip" href="/alisson/profil/spieler/105470" id="105470" title="Alisson">Alisson</a></span></div><span class="verletzt-table icons_sprite" title="Calf Injury - Return unknown"> </span></td></tr><tr><td>Goalkeeper</td></tr></table></td>,
#  <td class="" rowspan="2"><a href="#"><img alt="Alisson" class="bilderrahmen-fixed" src="https://tmssl.akamaized.net//images/portrait/small/105470-1447747290.jpg?lm=1447747302" title="Alisson"/></a></td>,
#  <td class="hauptlink"><div class="di nowrap"><span class="hide-for-small"><a class="spielprofil_tooltip" href="/alisson/profil/spieler/105470" id="105470" title="Alisson">Alisson</a></span></div><div class="di nowrap"><span class="show-for-small"><a class="spielprofil_tooltip" href="/alisson/profil/spieler/105470" id="105470" title="Alisson">Alisson</a></span></div><span class="verletzt-table icons_sprite" title="Calf Injury - Return unknown"> </span></td>,
#  <td>Goalkeeper</td>,
#  <td class="zentriert">Oct 2, 1992 (26)</td>,
#  <td class="zentriert"><img alt="Brazil" class="flaggenrahmen" src="https://tmssl.akamaized.net//images/flagge/verysmall/26.png?lm=1520611569" title="Brazil"/></td>,
#  <td class="zentriert">30.06.2024</td>,
#  <td class="rechts hauptlink">£72.00m <span class="icons_sprite green-arrow-ten" title="Previous Market Value: £58.50m"> </span></td>]

# %%
print(i)
print(data_values[i].find_all('td')[0].get('title'))
print(data_values[i].find_all('td')[1].contents[0].contents[0].find_all('a')[1].contents[0])
print(data_values[i].find_all('td')[5].contents[0])
print(data_values[i].find_all('td')[6].contents[0].get('title'))
print(data_values[i].find_all('td')[7].contents[0])
print(data_values[i].find_all('td')[8].contents[0])
# print(data_values[i].find_all('td')[9].contents[0].strip())
# Out:
# 0
# Goalkeeper
# Alisson
# Oct 2, 1992 (26)
# Brazil
# 30.06.2024
# £72.00m

# %%
for i in range(0,len(data_values),3):
#     print(i)
    if(data_values[i].find_all('td')[1].contents[0].name=='table'):
        print(i)
        print(data_values[i].find_all('td')[0].get('title'))
        print(data_values[i].find_all('td')[1].contents[0].contents[0].find_all('a')[1].contents[0])
        print(data_values[i].find_all('td')[5].contents[0])
        print(data_values[i].find_all('td')[6].contents[0].get('title'))
        print(data_values[i].find_all('td')[7].contents[0])
        print(data_values[i].find_all('td')[8].contents[0].strip())
    else:
        print(i)
        print(data_values[i].find_all('td')[0].get('title'))
        print(data_values[i].find_all('td')[3].contents[0].contents[0].contents[0].contents[0])
        print(data_values[i].find_all('td')[5].contents[0])
        print(data_values[i].find_all('td')[6].contents[0].get('title'))
        print(data_values[i].find_all('td')[7].contents[0])
        print(data_values[i].find_all('td')[8].contents[0].strip())
# Out:
# 0
# Goalkeeper
# Alisson
# Oct 2, 1992 (26)
# Brazil
# 30.06.2024
# £72.00m
# 3
# Goalkeeper
# Adrián
# Jan 3, 1987 (32)
# Spain
# 30.06.2021
# £4.50m
# 6
# Goalkeeper
# Andy Lonergan
# Oct 19, 1983 (35)
# England
# -
# £225k
# 9
# Defender
# Virgil van Dijk
# Jul 8, 1991 (28)
# Netherlands
# 30.06.2023
# £90.00m
# 12
# Defender
# Joe Gomez
# May 23, 1997 (22)
# England
# 30.06.2024
# £31.50m
# 15
# Defender
# Joel Matip
# Aug 8, 1991 (28)
# Cameroon
# 30.06.2020
# £31.50m
# 18
# Defender
# Dejan Lovren
# Jul 5, 1989 (30)
# Croatia
# 30.06.2021
# £18.00m
# 21
# Defender
# Andrew Robertson
# Mar 11, 1994 (25)
# Scotland
# 30.06.2024
# £54.00m
# 24
# Defender
# Trent Alexander-Arnold
# Oct 7, 1998 (20)
# England
# 30.06.2024
# £72.00m
# 27
# Defender
# Nathaniel Clyne
# Apr 5, 1991 (28)
# England
# 30.06.2020
# £10.80m
# 30
# Midfielder
# Fabinho
# Oct 23, 1993 (25)
# Brazil
# 30.06.2023
# £45.00m
# 33
# Midfielder
# Georginio Wijnaldum
# Nov 11, 1990 (28)
# Netherlands
# 30.06.2021
# £45.00m
# 36
# Midfielder
# Naby Keïta
# Feb 10, 1995 (24)
# Guinea
# 30.06.2023
# £45.00m
# 39
# Midfielder
# Jordan Henderson
# Jun 17, 1990 (29)
# England
# 30.06.2023
# £31.50m
# 42
# Midfielder
# Alex Oxlade-Chamberlain
# Aug 15, 1993 (26)
# England
# 30.06.2023
# £31.50m
# 45
# Midfielder
# James Milner
# Jan 4, 1986 (33)
# England
# 30.06.2020
# £13.50m
# 48
# Midfielder
# Adam Lallana
# May 10, 1988 (31)
# England
# 30.06.2020
# £13.50m
# 51
# Forward
# Sadio Mané
# Apr 10, 1992 (27)
# Senegal
# 30.06.2023
# £108.00m
# 54
# Forward
# Mohamed Salah
# Jun 15, 1992 (27)
# Egypt
# 30.06.2023
# £135.00m
# 57
# Forward
# Xherdan Shaqiri
# Oct 10, 1991 (27)
# Switzerland
# 30.06.2023
# £22.50m
# 60
# Forward
# Roberto Firmino
# Oct 2, 1991 (27)
# Brazil
# 30.06.2023
# £72.00m
# 63
# Forward
# Divock Origi
# Apr 18, 1995 (24)
# Belgium
# -
# £18.00m

# %%
url = 'https://www.transfermarkt.co.uk/norwich-city/kader/verein/1123/saison_id/2019'
headers = {"User-Agent":"Mozilla/5.0"}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
tables = soup.findAll("table")
data_values = tables[1].find('tbody').find_all('tr')

# %%
header=['Club','Position','Player_Name','DOB','Nation','Contract_Expiry','Value']
content=pd.DataFrame(columns=header)
content_list=[]

# %%
data_values[i]
# Out:
# <tr class="even">
# <td class="zentriert rueckennummer bg_Sturm" title="Forward"><div class="rn_nummer">7</div></td><td class="posrela" title=""><span class="wechsel-kader-wappen hide-for-small"><a href="/manchester-city/kadernaechstesaison/verein/281/saison_id/2019" title="on loan from Manchester City until May 31, 2020"><img alt="Manchester City" class="" src="https://tmssl.akamaized.net//images/wappen/kaderquad/281.png?lm=1467356331" title="on loan from Manchester City until May 31, 2020"/></a></span><a class="hide-for-small" href="/manchester-city/kadernaechstesaison/verein/281/saison_id/2019" title="on loan from Manchester City until May 31, 2020"><img class="wechsel-symbol" height="19px" src="/images/icons/leihe_beta_kader.png" width="19px"/></a><table class="inline-table" title=""><tr><td class="" rowspan="2"><a href="#"><img alt="Patrick Roberts" class="bilderrahmen-fixed" src="https://tmssl.akamaized.net//images/portrait/small/225452-1541162130.jpg?lm=1541162145" title="Patrick Roberts"/></a></td><td class="hauptlink"><div class="di nowrap"><span class="hide-for-small"><a class="spielprofil_tooltip" href="/patrick-roberts/profil/spieler/225452" id="225452" title="Patrick Roberts">Patrick Roberts</a></span></div><div class="di nowrap"><span class="show-for-small"><a class="spielprofil_tooltip" href="/patrick-roberts/profil/spieler/225452" id="225452" title="Patrick Roberts">P. Roberts</a></span></div></td></tr><tr><td>Right Winger</td></tr></table></td><td class="zentriert">Feb 5, 1997 (22)</td><td class="zentriert"><img alt="England" class="flaggenrahmen" src="https://tmssl.akamaized.net//images/flagge/verysmall/189.png?lm=1520611569" title="England"/></td><td class="zentriert">30.06.2022</td><td class="rechts hauptlink">£4.50m <span class="icons_sprite grey-block-ten" title="Previous Market Value: £4.50m"> </span></td></tr>

# %%
content
# Out:
# Empty DataFrame
# Columns: [Club, Position, Player_Name, DOB, Nation, Contract_Expiry, Value]
# Index: []

# %%
for i in range(0,len(data_values),3):
    content_list=[]
    if(data_values[i].find_all('td')[1].contents[0].name=='table'):
        content_list.append('Club Name')
        content_list.append(data_values[i].find_all('td')[0].get('title'))
        content_list.append(data_values[i].find_all('td')[1].contents[0].contents[0].find_all('a')[1].contents[0])
        content_list.append(data_values[i].find_all('td')[5].contents[0])
        content_list.append(data_values[i].find_all('td')[6].contents[0].get('title'))
        content_list.append(data_values[i].find_all('td')[7].contents[0])
        content_list.append(data_values[i].find_all('td')[8].contents[0].strip())
    else:
        content_list.append('Club Name')
        content_list.append(data_values[i].find_all('td')[0].get('title'))
        content_list.append(data_values[i].find_all('td')[3].contents[0].contents[0].contents[0].contents[0])
        content_list.append(data_values[i].find_all('td')[5].contents[0])
        content_list.append(data_values[i].find_all('td')[6].contents[0].get('title'))
        content_list.append(data_values[i].find_all('td')[7].contents[0])
        content_list.append(data_values[i].find_all('td')[8].contents[0].strip())
    print(content_list)
    content.loc[i] = content_list
# Out:
# ['Club Name', 'Goalkeeper', 'Tim Krul', 'Apr 3, 1988 (31)', 'Netherlands', '30.06.2022', '£3.60m']
# ['Club Name', 'Goalkeeper', 'Ralf Fährmann', 'Sep 27, 1988 (30)', 'Germany', '30.06.2020', '£3.60m']
# ['Club Name', 'Goalkeeper', 'Michael McGovern', 'Jul 12, 1984 (35)', 'Northern Ireland', '30.06.2021', '£315k']
# ['Club Name', 'Defender', 'Ben Godfrey', 'Jan 15, 1998 (21)', 'England', '30.06.2023', '£8.10m']
# ['Club Name', 'Defender', 'Christoph Zimmermann', 'Jan 12, 1993 (26)', 'Germany', '30.06.2023', '£3.15m']
# ['Club Name', 'Defender', 'Grant Hanley', 'Nov 20, 1991 (27)', 'Scotland', '30.06.2023', '£2.70m']
# ['Club Name', 'Defender', 'Timm Klose', 'May 9, 1988 (31)', 'Switzerland', '30.06.2022', '£2.70m']
# ['Club Name', 'Defender', 'Jamal Lewis', 'Jan 25, 1998 (21)', 'Northern Ireland', '30.06.2023', '£8.10m']
# ['Club Name', 'Defender', 'Philip Heise', 'Jun 20, 1991 (28)', 'Germany', '30.06.2022', '£900k']
# ['Club Name', 'Defender', 'Max Aarons', 'Jan 4, 2000 (19)', 'England', '30.06.2024', '£7.20m']
# ['Club Name', 'Defender', 'Sam Byram', 'Sep 16, 1993 (25)', 'England', '30.06.2023', '£3.15m']
# ['Club Name', 'Midfielder', 'Ibrahim Amadou', 'Apr 6, 1993 (26)', 'France', '30.06.2020', '£6.30m']
# ['Club Name', 'Midfielder', 'Tom Trybull', 'Mar 9, 1993 (26)', 'Germany', '30.06.2022', '£3.60m']
# ['Club Name', 'Midfielder', 'Alexander Tettey', 'Apr 4, 1986 (33)', 'Norway', '30.06.2020', '£1.80m']
# ['Club Name', 'Midfielder', 'Mario Vrancic', 'May 23, 1989 (30)', 'Bosnia-Herzegovina', '30.06.2021', '£3.15m']
# ['Club Name', 'Midfielder', 'Moritz Leitner', 'Dec 8, 1992 (26)', 'Germany', '30.06.2022', '£2.70m']
# ['Club Name', 'Midfielder', 'Kenny McLean', 'Jan 8, 1992 (27)', 'Scotland', '30.06.2021', '£2.25m']
# ['Club Name', 'Midfielder', 'Todd Cantwell', 'Feb 27, 1998 (21)', 'England', '30.06.2022', '£6.30m']
# ['Club Name', 'Midfielder', 'Marco Stiepermann', 'Feb 9, 1991 (28)', 'Germany', '30.06.2022', '£3.60m']
# ['Club Name', 'Forward', 'Onel Hernández', 'Feb 1, 1993 (26)', 'Cuba', '30.06.2023', '£3.60m']
# ['Club Name', 'Forward', 'Emiliano Buendía', 'Dec 25, 1996 (22)', 'Argentina', '30.06.2024', '£16.20m']
# ['Club Name', 'Forward', 'Patrick Roberts', 'Feb 5, 1997 (22)', 'England', '30.06.2022', '£4.50m']
# ['Club Name', 'Forward', 'Teemu Pukki', 'Mar 29, 1990 (29)', 'Finland', '30.06.2022', '£8.10m']
# ['Club Name', 'Forward', 'Josip Drmic', 'Aug 8, 1992 (27)', 'Switzerland', '30.06.2022', '£2.70m']
# ['Club Name', 'Forward', 'Dennis Srbeny', 'May 5, 1994 (25)', 'Germany', '30.06.2021', '£1.13m']

# %%
content
# Out:
#          Club    Position           Player_Name                DOB  \
# 0   Club Name  Goalkeeper              Tim Krul   Apr 3, 1988 (31)
# 3   Club Name  Goalkeeper         Ralf Fährmann  Sep 27, 1988 (30)
# 6   Club Name  Goalkeeper      Michael McGovern  Jul 12, 1984 (35)
# 9   Club Name    Defender           Ben Godfrey  Jan 15, 1998 (21)
# 12  Club Name    Defender  Christoph Zimmermann  Jan 12, 1993 (26)
# 15  Club Name    Defender          Grant Hanley  Nov 20, 1991 (27)
# 18  Club Name    Defender            Timm Klose   May 9, 1988 (31)
# 21  Club Name    Defender           Jamal Lewis  Jan 25, 1998 (21)
# 24  Club Name    Defender          Philip Heise  Jun 20, 1991 (28)
# 27  Club Name    Defender            Max Aarons   Jan 4, 2000 (19)
# 30  Club Name    Defender             Sam Byram  Sep 16, 1993 (25)
# 33  Club Name  Midfielder        Ibrahim Amadou   Apr 6, 1993 (26)
# 36  Club Name  Midfielder           Tom Trybull   Mar 9, 1993 (26)
# 39  Club Name  Midfielder      Alexander Tettey   Apr 4, 1986 (33)
# 42  Club Name  Midfielder         Mario Vrancic  May 23, 1989 (30)
# 45  Club Name  Midfielder        Moritz Leitner   Dec 8, 1992 (26)
# 48  Club Name  Midfielder          Kenny McLean   Jan 8, 1992 (27)
# 51  Club Name  Midfielder         Todd Cantwell  Feb 27, 1998 (21)
# 54  Club Name  Midfielder     Marco Stiepermann   Feb 9, 1991 (28)
# 57  Club Name     Forward        Onel Hernández   Feb 1, 1993 (26)
# 60  Club Name     Forward      Emiliano Buendía  Dec 25, 1996 (22)
# 63  Club Name     Forward       Patrick Roberts   Feb 5, 1997 (22)
# 66  Club Name     Forward           Teemu Pukki  Mar 29, 1990 (29)
# 69  Club Name     Forward           Josip Drmic   Aug 8, 1992 (27)
# 72  Club Name     Forward         Dennis Srbeny   May 5, 1994 (25)
#
#                 Nation Contract_Expiry    Value
# 0          Netherlands      30.06.2022   £3.60m
# 3              Germany      30.06.2020   £3.60m
# 6     Northern Ireland      30.06.2021    £315k
# 9              England      30.06.2023   £8.10m
# 12             Germany      30.06.2023   £3.15m
# 15            Scotland      30.06.2023   £2.70m
# 18         Switzerland      30.06.2022   £2.70m
# 21    Northern Ireland      30.06.2023   £8.10m
# 24             Germany      30.06.2022    £900k
# 27             England      30.06.2024   £7.20m
# 30             England      30.06.2023   £3.15m
# 33              France      30.06.2020   £6.30m
# 36             Germany      30.06.2022   £3.60m
# 39              Norway      30.06.2020   £1.80m
# 42  Bosnia-Herzegovina      30.06.2021   £3.15m
# 45             Germany      30.06.2022   £2.70m
# 48            Scotland      30.06.2021   £2.25m
# 51             England      30.06.2022   £6.30m
# 54             Germany      30.06.2022   £3.60m
# 57                Cuba      30.06.2023   £3.60m
# 60           Argentina      30.06.2024  £16.20m
# 63             England      30.06.2022   £4.50m
# 66             Finland      30.06.2022   £8.10m
# 69         Switzerland      30.06.2022   £2.70m
# 72             Germany      30.06.2021   £1.13m

# %%
content['Player Number'] = content.index

# %%
content.reset_index(level=0, inplace=True)

# %%
content.drop(["index"], axis = 1, inplace = True)

# %%
content

# %%
content_list

# %%
def get_club_details(name,link):
    url = link
    headers = {"User-Agent":"Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    tables = soup.findAll("table")
    data_values = tables[1].find('tbody').find_all('tr')
    for i in range(0,len(data_values),3):
        print(i)
        if(data_values[i].find_all('td')[1].contents[0].name=='table'):
            print(i)
            print(data_values[i].find_all('td')[0].get('title'))
            print(data_values[i].find_all('td')[1].contents[0].contents[0].find_all('a')[1].contents[0])
            print(data_values[i].find_all('td')[5].contents[0])
            print(data_values[i].find_all('td')[6].contents[0].get('title'))
            print(data_values[i].find_all('td')[7].contents[0])
            print(data_values[i].find_all('td')[8].contents[0].strip())
        else:
            print(i)
            print(data_values[i].find_all('td')[0].get('title'))
            print(data_values[i].find_all('td')[3].contents[0].contents[0].contents[0].contents[0])
            print(data_values[i].find_all('td')[5].contents[0])
            print(data_values[i].find_all('td')[6].contents[0].get('title'))
            print(data_values[i].find_all('td')[7].contents[0])
            print(data_values[i].find_all('td')[8].contents[0].strip())

# %%
url = 'https://www.transfermarkt.co.uk/norwich-city/kader/verein/1123/saison_id/2019'
headers = {"User-Agent":"Mozilla/5.0"}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
tables = soup.findAll("table")
data_values = tables[1].find('tbody').find_all('tr')

# %%
header=['Club','Position','Player_Name','DOB','Nation','Contract_Expiry','Value']
content=pd.DataFrame(columns=header)
content_list=[]

# %%
for i in range(0,len(data_values),3):
    content_list=[]
    if(data_values[i].find_all('td')[1].contents[0].name=='table'):
        content_list.append('ClubName')
        content_list.append(data_values[i].find_all('td')[0].get('title'))
        content_list.append(data_values[i].find_all('td')[1].contents[0].contents[0].find_all('a')[1].contents[0])
        content_list.append(data_values[i].find_all('td')[5].contents[0])
        content_list.append(data_values[i].find_all('td')[6].contents[0].get('title'))
        content_list.append(data_values[i].find_all('td')[7].contents[0])
        content_list.append(data_values[i].find_all('td')[8].contents[0].strip())
    else:
        content_list.append('ClubName')
        content_list.append(data_values[i].find_all('td')[0].get('title'))
        content_list.append(data_values[i].find_all('td')[3].contents[0].contents[0].contents[0].contents[0])
        content_list.append(data_values[i].find_all('td')[5].contents[0])
        content_list.append(data_values[i].find_all('td')[6].contents[0].get('title'))
        content_list.append(data_values[i].find_all('td')[7].contents[0])
        content_list.append(data_values[i].find_all('td')[8].contents[0].strip())
    print(content_list)
    content.loc[i] = content_list
content['Player Number'] = content.index
content.reset_index(level=0, inplace=True)
content.drop(["index"], axis = 1, inplace = True)

# %%
url = 'https://www.transfermarkt.co.uk/jumplist/startseite/wettbewerb/GB1'
headers = {"User-Agent":"Mozilla/5.0"}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
tables = soup.findAll("table")

# %%
def get_club_details(club_name,club_link):
    i_url = 'https://www.transfermarkt.co.uk/norwich-city/kader/verein/1123/saison_id/2019'
    i_headers = {"User-Agent":"Mozilla/5.0"}
    i_response = requests.get(i_url, headers=i_headers)
    i_soup = BeautifulSoup(i_response.content, 'html.parser')
    i_tables = i_soup.findAll("table")
    i_data_values = i_tables[1].find('tbody').find_all('tr')
    for i in range(0,len(i_data_values),3):
        header=['Club','Position','Player_Name','DOB','Nation','Contract_Expiry','Value']
        content=pd.DataFrame(columns=header)
        if(i_data_values[i].find_all('td')[1].contents[0].name=='table'):
            content_list.append(club_name)
            content_list.append(i_data_values[i].find_all('td')[0].get('title'))
            content_list.append(i_data_values[i].find_all('td')[1].contents[0].contents[0].find_all('a')[1].contents[0])
            content_list.append(i_data_values[i].find_all('td')[5].contents[0])
            content_list.append(i_data_values[i].find_all('td')[6].contents[0].get('title'))
            content_list.append(i_data_values[i].find_all('td')[7].contents[0])
            content_list.append(i_data_values[i].find_all('td')[8].contents[0].strip())
        else:
            content_list.append(club_name)
            content_list.append(i_data_values[i].find_all('td')[0].get('title'))
            content_list.append(i_data_values[i].find_all('td')[3].contents[0].contents[0].contents[0].contents[0])
            content_list.append(i_data_values[i].find_all('td')[5].contents[0])
            content_list.append(i_data_values[i].find_all('td')[6].contents[0].get('title'))
            content_list.append(i_data_values[i].find_all('td')[7].contents[0])
            content_list.append(i_data_values[i].find_all('td')[8].contents[0].strip())
        print(content_list)
        content.loc[i] = content_list
    content['Player Number'] = content.index
    content.reset_index(level=0, inplace=True)
    content.drop(["index"], axis = 1, inplace = True)
    return content

# %%
main_df = pd.DataFrame(columns=header)
for i in range(0,len(tables[3].find('tbody').find_all('tr'))):
    club_df = pd.DataFrame(columns=header)
    club_name = tables[3].find('tbody').find_all('tr')[i].find('td').find('img').get('alt')
    club_link = (tables[3].find('tbody').find_all('tr')[i].find('td').find('a').get('href'))
#     club_df=club_link[club_link.find('/')+1:club_link.find('/',2)]
#     club_df = club_df.replace('-','_')
#     club_df = club_df + '_df'
#     print(club_df)
    club_link = 'https://www.transfermarkt.co.uk'+club_link
    club_link=club_link.replace("startseite", "kader")
    print(club_name,club_link)
    club_df = get_club_details(club_name,club_link)
# Out:
# Manchester City https://www.transfermarkt.co.uk/manchester-city/kader/verein/281/saison_id/2019
# ['Club Name', 'Forward', 'Dennis Srbeny', 'May 5, 1994 (25)', 'Germany', '30.06.2021', '£1.13m', 'Manchester City', 'Goalkeeper', 'Tim Krul', 'Apr 3, 1988 (31)', 'Netherlands', '30.06.2022', '£3.60m']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-184-a675679a7554> in <module>
#      11     club_link=club_link.replace("startseite", "kader")
#      12     print(club_name,club_link)
# ---> 13     club_df = get_club_details(club_name,club_link)
#
# <ipython-input-183-4aa2940e5f1c> in get_club_details(club_name, club_link)
#      26             content_list.append(i_data_values[i].find_all('td')[8].contents[0].strip())
#      27         print(content_list)
# ---> 28         content.loc[i] = content_list
#      29     content['Player Number'] = content.index
#      30     content.reset_index(level=0, inplace=True)
#
# c:\users\akhil_s_bhat\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     192             key = com._apply_if_callable(key, self.obj)
#     193         indexer = self._get_setitem_indexer(key)
# --> 194         self._setitem_with_indexer(indexer, value)
#     195
#     196     def _has_valid_type(self, k, axis):
#
# c:\users\akhil_s_bhat\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     437                         if is_list_like_indexer(value):
#     438                             if len(value) != len(self.obj.columns):
# --> 439                                 raise ValueError("cannot set a row with "
#     440                                                  "mismatched columns")
#     441
#
# ValueError: cannot set a row with mismatched columns

# %%
data_values = tables[1].find('tbody').find_all('tr')
