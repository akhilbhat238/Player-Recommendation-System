# %%
import pandas as pd
import numpy as np

# %%
ranking_df = pd.read_csv('..\\Consolidated Data\\Team Rankings_corrected.csv',encoding = "utf-8")

# %%
ranking_df = ranking_df.drop(['Unnamed: 0'],axis=1)

# %%
ranking_df[ranking_df['Tier']==2]
# Out:
#                 Team  Tier
# 4  Manchester United     2
# 5  Tottenham Hotspur     2
# 6    Manchester City     2
# 7    Atlético Madrid     2
# 8           Juventus     2
# 9          Liverpool     2

# %%
ranking_teams=ranking_df['Team'].unique()

# %%
tier1_teams = ranking_teams[0:4]

# %%
dataset_teams = pd.read_csv('..\\Consolidated Data\\players_20.csv')

# %%
dataset_teams = dataset_teams['club'].unique()

# %%
dataset_teams
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Atlético Madrid', 'Real Madrid', 'Manchester City', 'Liverpool',
#        'Napoli', 'Tottenham Hotspur', 'Manchester United', 'Chelsea',
#        'FC Bayern München', 'Inter', 'Borussia Dortmund', 'Arsenal',
#        'Valencia CF', 'Lazio', 'Milan', 'Sporting CP',
#        'Olympique Lyonnais', 'RB Leipzig', 'Ajax', 'LA Galaxy',
#        'Atalanta', 'RC Celta', 'Bayer 04 Leverkusen', 'Real Betis',
#        'FC Porto', 'SV Werder Bremen', 'West Ham United',
#        'Wolverhampton Wanderers', 'AS Saint-Étienne', 'Torino',
#        'Dalian YiFang FC', 'Borussia Mönchengladbach', 'Roma',
#        'Guangzhou Evergrande Taobao FC', 'SL Benfica',
#        'Medipol Başakşehir FK', 'Everton', 'VfL Wolfsburg',
#        'Crystal Palace', 'Getafe CF', 'Shanghai SIPG FC',
#        'Eintracht Frankfurt', 'Olympique de Marseille', 'Hertha BSC',
#        'RSC Anderlecht', 'Villarreal CF', 'Sampdoria', 'Leicester City',
# ...

# %%
for i in range(0,len(tier1_teams)):
    print(i)
    print(tier1_teams[i])
    for j in range(0,len(dataset_teams)):
        if (tier1_teams[i] in dataset_teams[j]):
            print(j)
            print(dataset_teams[j])
# Out:
# 0
# Chelsea
# 10
# Chelsea
# 1
# FC Bayern München
# 11
# FC Bayern München
# 2
# FC Barcelona
# 0
# FC Barcelona
# 3
# Real Madrid
# 4
# Real Madrid

# %%
tier2_teams = ranking_df[ranking_df['Tier']==2]

tier2_teams = tier2_teams.reset_index()

tier2_teams = tier2_teams.drop(['index'],axis=1)

# %%
for i in range(0,len(tier2_teams)):
    print(i)
    print(tier2_teams.iloc[i]['Team'])
    for j in range(0,len(dataset_teams)):
        if (tier2_teams.iloc[i]['Team'] in dataset_teams[j]):
            print(j)
            print(dataset_teams[j])
# Out:
# 0
# Manchester United
# 9
# Manchester United
# 1
# Tottenham Hotspur
# 8
# Tottenham Hotspur
# 2
# Manchester City
# 5
# Manchester City
# 3
# Atlético Madrid
# 3
# Atlético Madrid
# 4
# Juventus
# 1
# Juventus
# 5
# Liverpool
# 6
# Liverpool

# %%
tier3_teams = ranking_df[ranking_df['Tier']==3]

tier3_teams = tier3_teams.reset_index()

tier3_teams = tier3_teams.drop(['index'],axis=1)

# %%
for i in range(0,len(tier3_teams)):
    print(i)
    print(tier3_teams.iloc[i]['Team'])
    for j in range(0,len(dataset_teams)):
        if (tier3_teams.iloc[i]['Team'] in dataset_teams[j]):
            print(j)
            print(dataset_teams[j])
# Out:
# 0
# Arsenal
# 14
# Arsenal
# 479
# Arsenal de Sarandí
# 1
# Milan
# 17
# Milan
# 2
# Roma
# 35
# Roma
# 381
# Romania
# 3
# AS Monaco
# 51
# AS Monaco
# 4
# Ajax
# 21
# Ajax

# %%
tier4_teams = ranking_df[ranking_df['Tier']==4]

tier4_teams = tier4_teams.reset_index()

tier4_teams = tier4_teams.drop(['index'],axis=1)

for i in range(0,len(tier4_teams)):
    print(i)
    print(tier4_teams.iloc[i]['Team'])
    for j in range(0,len(dataset_teams)):
        if (tier4_teams.iloc[i]['Team'] in dataset_teams[j]):
            print(j)
            print(dataset_teams[j])
# Out:
# 0
# Bayer 04 Leverkusen
# 25
# Bayer 04 Leverkusen
# 1
# Napoli
# 7
# Napoli
# 2
# Everton
# 39
# Everton
# 390
# CD Everton de Viña del Mar
# 3
# Valencia CF
# 15
# Valencia CF
# 4
# Sevilla FC
# 55
# Sevilla FC
# 5
# Villarreal CF
# 48
# Villarreal CF
# 6
# PSV
# 61
# PSV
# 7
# FC Schalke 04
# 100
# FC Schalke 04
# 8
# Borussia Dortmund
# 13
# Borussia Dortmund
# 9
# Inter
# 12
# Inter
# 132
# Internacional

# %%
tier5_teams = ranking_df[ranking_df['Tier']==5]

tier5_teams = tier5_teams.reset_index()

tier5_teams = tier5_teams.drop(['index'],axis=1)

for i in range(0,len(tier5_teams)):
    print(i)
    print(tier5_teams.iloc[i]['Team'])
    for j in range(0,len(dataset_teams)):
        if (tier5_teams.iloc[i]['Team'] in dataset_teams[j]):
            print(j)
            print(dataset_teams[j])
# Out:
# 0
# West Ham United
# 29
# West Ham United
# 1
# Real Sociedad
# 57
# Real Sociedad
# 2
# RC Celta
# 24
# RC Celta
# 3
# Torino
# 32
# Torino
# 4
# Southampton
# 117
# Southampton
# 5
# Aston Villa
# 106
# Aston Villa
# 6
# Hertha BSC
# 46
# Hertha BSC
# 7
# TSG 1899 Hoffenheim
# 58
# TSG 1899 Hoffenheim
# 8
# Real Betis
# 26
# Real Betis
# 9
# Fiorentina
# 113
# Fiorentina
# 10
# Lazio
# 16
# Lazio
# 11
# Athletic Club de Bilbao
# 62
# Athletic Club de Bilbao
# 12
# RCD Espanyol
# 92
# RCD Espanyol
# 13
# FC Girondins de Bordeaux
# 86
# FC Girondins de Bordeaux
# 14
# Stade Rennais FC
# 146
# Stade Rennais FC
# 15
# SV Werder Bremen
# 28
# SV Werder Bremen
# 16
# Udinese
# 137
# Udinese
# 17
# Getafe CF
# 42
# Getafe CF
# 18
# VfL Wolfsburg
# 40
# VfL Wolfsburg
# 19
# Olympique de Marseille
# 45
# Olympique de Marseille
# 20
# Olympique Lyonnais
# 19
# Olympique Lyonnais
# 21
# Leicester City
# 50
# Leicester City
# 22
# Paris Saint-Germain
# 2
# Paris Saint-Germain

# %%
tier6_teams = ranking_df[ranking_df['Tier']==6]

tier6_teams = tier6_teams.reset_index()

tier6_teams = tier6_teams.drop(['index'],axis=1)

for i in range(0,len(tier6_teams)):
    print(i)
    print(tier6_teams.iloc[i]['Team'])
    for j in range(0,len(dataset_teams)):
        if (tier6_teams.iloc[i]['Team'] in dataset_teams[j]):
            print(j)
            print(dataset_teams[j])
# Out:
# 0
# Borussia Mönchengladbach
# 34
# Borussia Mönchengladbach
# 1
# Atalanta
# 23
# Atalanta
# 2
# Newcastle United
# 97
# Newcastle United
# 3
# AZ Alkmaar
# 174
# AZ Alkmaar
# 4
# Feyenoord
# 110
# Feyenoord
# 5
# SC Heerenveen
# 473
# SC Heerenveen
# 6
# FC Groningen
# 236
# FC Groningen
# 7
# Vitesse
# 297
# Vitesse
# 8
# FC Utrecht
# 201
# FC Utrecht
# 9
# FC Twente
# 374
# FC Twente
# 10
# Sampdoria
# 49
# Sampdoria
# 11
# LOSC Lille
# 87
# LOSC Lille
# 12
# Genoa
# 125
# Genoa
# 13
# AS Saint-Étienne
# 31
# AS Saint-Étienne
# 14
# OGC Nice
# 96
# OGC Nice
# 15
# Eintracht Frankfurt
# 44
# Eintracht Frankfurt

# %%
tier7_teams = ranking_df[ranking_df['Tier']==7]

tier7_teams = tier7_teams.reset_index()

tier7_teams = tier7_teams.drop(['index'],axis=1)

for i in range(0,len(tier7_teams)):
    print(i)
    print(tier7_teams.iloc[i]['Team'])
    for j in range(0,len(dataset_teams)):
        if (tier7_teams.iloc[i]['Team'] in dataset_teams[j]):
            print(j)
            print(dataset_teams[j])
# Out:
# 0
# Crystal Palace
# 41
# Crystal Palace
# 1
# Bournemouth
# 79
# Bournemouth
# 2
# Brighton & Hove Albion
# 98
# Brighton & Hove Albion
# 3
# Burnley
# 118
# Burnley
# 4
# Norwich City
# 109
# Norwich City
# 5
# Sheffield United
# 202
# Sheffield United
# 6
# Watford
# 77
# Watford
# 7
# Wolverhampton Wanderers
# 30
# Wolverhampton Wanderers
# 8
# Granada CF
# 215
# Granada CF
# 9
# Levante UD
# 72
# Levante UD
# 10
# CA Osasuna
# 225
# CA Osasuna
# 11
# Deportivo Alavés
# 63
# Deportivo Alavés
# 12
# Real Valladolid CF
# 81
# Real Valladolid CF
# 13
# RCD Mallorca
# 271
# RCD Mallorca
# 14
# SD Eibar
# 101
# SD Eibar
# 15
# CD Leganés
# 130
# CD Leganés
# 16
# RB Leipzig
# 20
# RB Leipzig
# 17
# SC Paderborn 07
# 408
# SC Paderborn 07
# 18
# FC Augsburg
# 140
# FC Augsburg
# 19
# 1. FC Köln
# 78
# 1. FC Köln
# 20
# Fortuna Düsseldorf
# 172
# Fortuna Düsseldorf
# 21
# SC Freiburg
# 145
# SC Freiburg
# 22
# 1. FSV Mainz 05
# 135
# 1. FSV Mainz 05
# 23
# 1. FC Union Berlin
# 187
# ...
