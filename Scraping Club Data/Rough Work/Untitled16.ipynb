# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
headers = {"User-Agent":"Mozilla/5.0"}
response = requests.get('https://www.transfermarkt.com/laliga/startseite/wettbewerb/ES1', headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
tables = soup.findAll("table")

# %%
team_data = tables[3].findAll("tbody")

# %%
def get_transfer_spends(url):
    tx_array = []
    headers = {"User-Agent":"Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    tables = soup.findAll("table")
    for i in range(0,6):
        footer = tables[i].find('tfoot')
        footer.find('td').contents[0]
        x=footer.find('td').contents[0]
        tx_array.append(x)
    return tx_array

# %%
team_array=[]
for i in team_data[0].findAll("td", {'class':'zentriert no-border-rechts'}):
    team_name = (i.find('a').find('img')['alt'])
    team_array.append(team_name)
    team_link = (i.find('a')['href'])
    team_link.find('/saison')
    team_short_link = team_link[0:team_link.find('/saison')]
    transfer_link = team_short_link.replace('startseite','alletransfers',1)
    full_tx_link = 'https://www.transfermarkt.com' + transfer_link
    spends = get_transfer_spends(full_tx_link)
    team_array.append(spends)

# %%
team_array
# Out:
# ['Real Madrid',
#  ['€307.50m', '€130.00m', '€162.75m', '€134.10m', '€40.50m', '€128.50m'],
#  'FC Barcelona',
#  ['€255.00m', '€156.40m', '€129.10m', '€134.05m', '€374.50m', '€232.50m'],
#  'Atlético Madrid',
#  ['€56.00m', '€243.50m', '€313.10m', '€160.50m', '€64.90m', '€102.00m'],
#  'Valencia CF',
#  ['€12.00m', '€75.00m', '€45.00m', '€127.00m', '€68.80m', '€55.00m'],
#  'Real Sociedad',
#  ['€250k', '€21.25m', '€9.50m', '€12.00m', '€30.80m', '€21.50m'],
#  'Real Betis Balompié',
#  ['€95.75m', '€69.50m', '€42.50m', '€48.25m', '€38.50m', '€27.07m'],
#  'Sevilla FC',
#  ['0', '€158.75m', '€101.20m', '€79.25m', '€91.25m', '€78.05m'],
#  'Celta de Vigo',
#  ['€22.90m', '€19.65m', '€29.50m', '€34.80m', '€25.80m', '€13.20m'],
#  'Athletic Bilbao',
#  ['0', '0', '0', '€32.90m', '€80.00m', '€32.00m'],
#  'Villarreal CF',
#  ['€21.80m', '€62.00m', '€92.90m', '€59.80m', '€46.10m', '€67.30m'],
#  'Getafe CF',
#  ['€12.00m', '€2.25m', '€27.25m', '€5.00m', '€12.90m', '€1.60m'],
#  'RCD Espanyol Barcelona',
#  ['€18.50m', '€59.00m', '€22.60m', '€30.80m', '€17.05m', '€7.70m'],
#  'CD Leganés',
#  ['€21.20m', '€2.02m', '€18.70m', '€23.00m', '€6.10m', '€130k'],
#  'Levante UD',
#  ['€12.60m', '€4.80m', '€26.00m', '€33.00m', '€9.10m', '€14.05m'],
#  'Real Valladolid CF',
#  ['€1.00m', '€8.00m', '€10.10m', '0', '€50k', '€3.40m'],
#  'Deportivo Alavés',
#  ['€10.77m', '€18.00m', '€10.02m', '€9.00m', '€12.33m', '€7.50m'],
#  'SD Eibar',
#  ['€17.10m', '€27.00m', '€8.00m', '€7.75m', '€6.95m', '€10.00m'],
#  'RCD Mallorca',
#  ['€7.00m', '0', '€400k', '0', '€100k', '€3.50m'],
#  'CA Osasuna',
#  ['€250k', '€13.45m', '0', '€1.60m', '€3.45m', '€4.15m'],
#  'Granada CF',
#  ['€7.25m', '€300k', '€400k', '€3.32m', '€130k', '€4.99m']]

# %%
team_array[0]
# Out:
# 'Real Madrid'

# %%
team_df = pd.DataFrame(columns =['Team','Arrivals_2019','Departures_2019','Arrivals_2018','Departures_2018','Arrivals_2017','Departures_2017'])

# %%
clean_array = []
for i in range(0,len(team_array)):
    print(i)
    print(team_array[i])
    if(i%2==0):
        print('x')
        clean_array.append(team_array[i])
    else:
        for j in team_array[i]:
#             print(j)
            clean_array.append(j)
# Out:
# 0
# Real Madrid
# x
# 1
# ['€307.50m', '€130.00m', '€162.75m', '€134.10m', '€40.50m', '€128.50m']
# 2
# FC Barcelona
# x
# 3
# ['€255.00m', '€156.40m', '€129.10m', '€134.05m', '€374.50m', '€232.50m']
# 4
# Atlético Madrid
# x
# 5
# ['€56.00m', '€243.50m', '€313.10m', '€160.50m', '€64.90m', '€102.00m']
# 6
# Valencia CF
# x
# 7
# ['€12.00m', '€75.00m', '€45.00m', '€127.00m', '€68.80m', '€55.00m']
# 8
# Real Sociedad
# x
# 9
# ['€250k', '€21.25m', '€9.50m', '€12.00m', '€30.80m', '€21.50m']
# 10
# Real Betis Balompié
# x
# 11
# ['€95.75m', '€69.50m', '€42.50m', '€48.25m', '€38.50m', '€27.07m']
# 12
# Sevilla FC
# x
# 13
# ['0', '€158.75m', '€101.20m', '€79.25m', '€91.25m', '€78.05m']
# 14
# Celta de Vigo
# x
# 15
# ['€22.90m', '€19.65m', '€29.50m', '€34.80m', '€25.80m', '€13.20m']
# 16
# Athletic Bilbao
# x
# 17
# ['0', '0', '0', '€32.90m', '€80.00m', '€32.00m']
# 18
# Villarreal CF
# x
# 19
# ['€21.80m', '€62.00m', '€92.90m', '€59.80m', '€46.10m', '€67.30m']
# 20
# Getafe CF
# x
# 21
# ['€12.00m', '€2.25m', '€27.25m', '€5.00m', '€12.90m', '€1.60m']
# 22
# RCD Espanyol Barcelona
# x
# 23
# ['€18.50m', '€59.00m', '€22.60m', '€30.80m', '€17.05m', '€7.70m']
# 24
# CD Leganés
# x
# 25
# ['€21.20m', '€2.02m', '€18.70m', '€23.00m', '€6.10m', '€130k']
# 26
# Levante UD
# x
# 27
# ['€12.60m', '€4.80m', '€26.00m', '€33.00m', '€9.10m', '€14.05m']
# 28
# Real Valladolid CF
# x
# 29
# ['€1.00m', '€8.00m', '€10.10m', '0', '€50k', '€3.40m']
# 30
# Deportivo Alavés
# x
# 31
# ['€10.77m', '€18.00m', '€10.02m', '€9.00m', '€12.33m', '€7.50m']
# 32
# SD Eibar
# x
# 33
# ['€17.10m', '€27.00m', '€8.00m', '€7.75m', '€6.95m', '€10.00m']
# 34
# RCD Mallorca
# x
# 35
# ['€7.00m', '0', '€400k', '0', '€100k', '€3.50m']
# 36
# CA Osasuna
# x
# 37
# ['€250k', '€13.45m', '0', '€1.60m', '€3.45m', '€4.15m']
# 38
# Granada CF
# x
# 39
# ['€7.25m', '€300k', '€400k', '€3.32m', '€130k', '€4.99m']

# %%
clean_array
# Out:
# ['Real Madrid',
#  '€307.50m',
#  '€130.00m',
#  '€162.75m',
#  '€134.10m',
#  '€40.50m',
#  '€128.50m',
#  'FC Barcelona',
#  '€255.00m',
#  '€156.40m',
#  '€129.10m',
#  '€134.05m',
#  '€374.50m',
#  '€232.50m',
#  'Atlético Madrid',
#  '€56.00m',
#  '€243.50m',
#  '€313.10m',
#  '€160.50m',
#  '€64.90m',
#  '€102.00m',
#  'Valencia CF',
#  '€12.00m',
#  '€75.00m',
#  '€45.00m',
#  '€127.00m',
#  '€68.80m',
#  '€55.00m',
#  'Real Sociedad',
#  '€250k',
#  '€21.25m',
#  '€9.50m',
#  '€12.00m',
#  '€30.80m',
#  '€21.50m',
#  'Real Betis Balompié',
#  '€95.75m',
#  '€69.50m',
#  '€42.50m',
#  '€48.25m',
#  '€38.50m',
#  '€27.07m',
#  'Sevilla FC',
#  '0',
#  '€158.75m',
#  '€101.20m',
#  '€79.25m',
#  '€91.25m',
#  '€78.05m',
#  'Celta de Vigo',
#  '€22.90m',
#  '€19.65m',
#  '€29.50m',
#  '€34.80m',
#  '€25.80m',
#  '€13.20m',
#  'Athletic Bilbao',
#  '0',
#  '0',
#  '0',
#  '€32.90m',
#  '€80.00m',
#  '€32.00m',
#  'Villarreal CF',
#  '€21.80m',
#  '€62.00m',
#  '€92.90m',
#  '€59.80m',
#  '€46.10m',
#  '€67.30m',
#  'Getafe CF',
#  '€12.00m',
#  '€2.25m',
#  '€27.25m',
#  '€5.00m',
#  '€12.90m',
#  '€1.60m',
#  'RCD Espanyol Barcelona',
#  '€18.50m',
#  '€59.00m',
#  '€22.60m',
#  '€30.80m',
#  '€17.05m',
#  '€7.70m',
#  'CD Leganés',
#  '€21.20m',
#  '€2.02m',
#  '€18.70m',
#  '€23.00m',
#  '€6.10m',
#  '€130k',
#  'Levante UD',
#  '€12.60m',
#  '€4.80m',
#  '€26.00m',
#  '€33.00m',
#  '€9.10m',
#  '€14.05m',
#  'Real Valladolid CF',
#  '€1.00m',
#  '€8.00m',
#  '€10.10m',
#  '0',
#  '€50k',
#  '€3.40m',
#  'Deportivo Alavés',
#  '€10.77m',
#  '€18.00m',
#  '€10.02m',
#  '€9.00m',
#  '€12.33m',
#  '€7.50m',
#  'SD Eibar',
#  '€17.10m',
#  '€27.00m',
#  '€8.00m',
#  '€7.75m',
#  '€6.95m',
#  '€10.00m',
#  'RCD Mallorca',
#  '€7.00m',
#  '0',
#  '€400k',
#  '0',
#  '€100k',
#  '€3.50m',
#  'CA Osasuna',
#  '€250k',
#  '€13.45m',
#  '0',
#  '€1.60m',
#  '€3.45m',
#  '€4.15m',
#  'Granada CF',
#  '€7.25m',
#  '€300k',
#  '€400k',
#  '€3.32m',
#  '€130k',
#  '€4.99m']
