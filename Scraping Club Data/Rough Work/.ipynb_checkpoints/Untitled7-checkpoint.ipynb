# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
data_url = 'https://en.wikipedia.org/wiki/List_of_FA_Cup_Finals'
page = requests.get(data_url)
soup = BeautifulSoup(page.content,'html.parser')

# %%
tables = soup.findAll("table")

# %%
table_to_use = tables[1]

# %%
fa_cup_df = pd.DataFrame(columns=['Season','Winner','Runner'])

# %%
fa_cup_df.loc[0]= ['A','B','C']

# %%
fa_cup_df

# %%
all_tr = table_to_use.find_all('tr')

# %%
all_tr[1].find_all('td')[0].contents[0].contents[0]

# %%
all_tr[1].find_all('th')[0].contents[0].contents[0]

# %%
all_tr[1].find_all('td')[2].contents[0].contents[0]

# %%
all_tr[1].find_all('td')[3].contents[0].contents[0]

# %%
all_tr[141].find_all('td')

# %%
for i in range(1,len(all_tr)):
    idd = (i)
    season = (all_tr[i].find_all('td')[0].contents[0].contents[0].contents[0])
    winner = (all_tr[i].find_all('th')[0].contents[0].contents[0])
    runner = (all_tr[i].find_all('td')[2].contents[0].contents[0])
    fa_cup_df.loc[idd]= [season,winner,runner]

# %%
fa_cup_df

# %%
data_url = 'https://en.wikipedia.org/wiki/Copa_del_Rey#List_of_finals'
page = requests.get(data_url)
soup = BeautifulSoup(page.content,'html.parser')

# %%
tables = soup.findAll("table")
table_to_use = tables[2]

# %%
table_to_use

# %%
all_tr = table_to_use.find_all('tr')

# %%
all_tr[1].find_all('td')[0].contents[0].contents[0]

# %%
all_tr[1].find_all('td')[1].contents[0].contents[0]

# %%
all_tr[1].find_all('td')[3].contents[0].contents[0]

# %%
copa_df = pd.DataFrame(columns=['Season','Winner','Runner'])

# %%
for i in range(1,len(all_tr)):
#     idd = (i)
#     season = (all_tr[i].find_all('td')[0].contents[0].contents[0])
#     winner = (all_tr[i].find_all('td')[1].contents[0].contents[0])
#     runner = (all_tr[i].find_all('td')[3].contents[0].contents[0])
#     copa_df.loc[idd]= [season,winner,runner]
    print(i)
    print(all_tr[i].find_all('td')[0].contents[0].contents[0])

# %%
data_url = 'https://www.footballhistory.org/tournament/coppa-italia.html'
page = requests.get(data_url)
soup = BeautifulSoup(page.content,'html.parser')

# %%
tables = soup.findAll("table")
table_to_use = tables[0]
cp_it_df = pd.DataFrame(columns=['Season','Winner','Runner'])

# %%
all_tr = table_to_use.find_all('tr')

# %%
all_tr[1].find_all('td')[0].contents[0]

# %%
all_tr[1].find_all('td')[1].contents[0]

# %%
all_tr[1].find_all('td')[2].contents[0]

# %%
for i in range(1,len(all_tr)):
    print(all_tr[i].find_all('td')[0].contents[0])
    print(all_tr[i].find_all('td')[1].contents[0])
    print(all_tr[i].find_all('td')[2].contents[0])

# %%
data_url = 'https://en.wikipedia.org/wiki/DFB-Pokal#Finals'
page = requests.get(data_url)
soup = BeautifulSoup(page.content,'html.parser')

# %%
tables = soup.findAll("table")
table_to_use = tables[2]
cp_it_df = pd.DataFrame(columns=['Season','Winner','Runner'])

# %%
table_to_use

# %%
all_tr = table_to_use.find_all('tr')

# %%
all_tr[1].find_all('td')[0].contents[0].contents[0].contents[0]
all_tr[1].find_all('td')[1].contents[0].contents[0]
all_tr[1].find_all('td')[2].contents[0].contents[0]

# %%
for i in range(1,len(all_tr)):
    print(all_tr[i].find_all('td')[0].contents[0].contents[0].contents[0])
    print(all_tr[i].find_all('td')[1].contents[0].contents[0].contents[0])
    print(all_tr[i].find_all('td')[2].contents[0].contents[0])

# %%
data_url = 'https://en.wikipedia.org/wiki/List_of_Coupe_de_France_finals'
page = requests.get(data_url)
soup = BeautifulSoup(page.content,'html.parser')

# %%
tables = soup.findAll("table")
table_to_use = tables[0]
cp_it_df = pd.DataFrame(columns=['Season','Winner','Runner'])

# %%
table_to_use

# %%
all_tr = table_to_use.find_all('tr')

# %%
all_tr[1].find_all('td')[0].contents[0].rstrip()
# Out:
# '5 May 1918'

# %%
all_tr[1].find_all('td')[1].contents[0].contents[0]
all_tr[1].find_all('td')[2].contents[0].contents[0]
# Out:
# 'FC Lyon'

# %%
all_tr[1].find_all('td')[0].contents[0].rstrip()
all_tr[1].find_all('td')[1].contents[0].contents[0]
all_tr[1].find_all('td')[2].contents[0].contents[0]
# Out:
# 'FC Lyon'

# %%
all_tr[2].find_all('td')[1].contents[0].rstrip()
# Out:
# 'CASG Paris'

# %%
for i in range(90,len(all_tr)):
    print(all_tr[i].find_all('td')[0].contents[0].rstrip())
    print(all_tr[i].find_all('td')[1].contents[0].contents[0])
    print(all_tr[i].find_all('td')[2].contents[0].contents[0])
# Out:
# 11 May 2002
# Lorient
# Bastia
# 31 May 2003
# Auxerre
# Paris Saint-Germain
# 29 May 2004
# Paris Saint-Germain
# LB Châteauroux
# 4 June 2005
# AJ Auxerre
# CS Sedan
# 29 April 2006
# Paris Saint-Germain
# Marseille
# 12 May 2007
# Sochaux
# Marseille
# 24 May 2008
# Lyon
# Paris Saint-Germain
# 9 May 2009
# Guingamp
# Rennes
# 1 May 2010
# Paris Saint-Germain
# Monaco
# 14 May 2011
# Lille
# Paris Saint-Germain
# 28 April 2012
# Lyon
# US Quevilly
# 31 May 2013
# Bordeaux
# Evian
# 3 May 2014
# Guingamp
# Rennes
# 30 May 2015
# Paris Saint-Germain
# Auxerre
# 21 May 2016
# Paris Saint-Germain
# Marseille
# 27 May 2017
# Paris Saint-Germain
# Angers
# 8 May 2018
# Paris Saint-Germain
# Les Herbiers
# 27 April 2019
# Rennes
# Paris Saint-Germain

# %%
https://en.wikipedia.org/wiki/KNVB_Cup

# %%
data_url = 'https://en.wikipedia.org/wiki/KNVB_Cup'
page = requests.get(data_url)
soup = BeautifulSoup(page.content,'html.parser')

# %%
tables = soup.findAll("table")
table_to_use = tables[1]
cp_it_df = pd.DataFrame(columns=['Season','Winner','Runner'])

# %%
table_to_use

all_tr = table_to_use.find_all('tr')

# %%
all_tr
# Out:
# [<tr>
#  <th>Season
#  </th>
#  <th>Winner
#  </th>
#  <th>Scorers
#  </th>
#  <th>Result
#  </th>
#  <th>Runner-up
#  </th>
#  <th>Scorers
#  </th>
#  <th>Venue
#  </th>
#  <th>Att.
#  </th></tr>, <tr>
#  <td>1898–99</td>
#  <td><a href="/wiki/RAP_(football_club)" title="RAP (football club)">RAP Amsterdam</a></td>
#  <td></td>
#  <td>1–0 <a class="mw-redirect" href="/wiki/Extra-time" title="Extra-time">aet</a></td>
#  <td><a href="/wiki/HVV_Den_Haag" title="HVV Den Haag">HVV Den Haag</a></td>
#  <td></td>
#  <td></td>
#  <td>
#  </td></tr>, <tr bgcolor="#F4FAFF">
#  <td>1899–1900</td>
#  <td><a class="new" href="/w/index.php?title=Velocitas_Breda&amp;action=edit&amp;redlink=1" title="Velocitas Breda (page does not exist)">Velocitas Breda</a></td>
#  <td></td>
#  <td>3–1</td>
#  <td><a class="mw-redirect" href="/wiki/Ajax_Sportman_Combinatie" title="Ajax Sportman Combinatie">Ajax Leiden</a></td>
#  <td></td>
#  <td></td>
#  <td>
#  </td></tr>, <tr>
#  <td>1900–01</td>
# ...

# %%
all_tr[102].find_all('td')[0].contents[0].contents[0]
# Out:
# '2005–06'

# %%
all_tr[102].find_all('td')[1].contents[0].contents[0]
# Out:
# 'Ajax'

# %%
all_tr[102].find_all('td')[4].contents[0].contents[0]
# Out:
# 'PSV'

# %%
for i in range(102,len(all_tr)):
    if(i!=107):
        print(i)
        print(all_tr[i].find_all('td')[0].contents[0].contents[0])
        print(all_tr[i].find_all('td')[1].contents[0].contents[0])
        print(all_tr[i].find_all('td')[4].contents[0].contents[0])
# Out:
# 102
# 2005–06
# Ajax
# PSV
# 103
# 2006–07
# Ajax
# AZ
# 104
# 2007–08
# Feyenoord
# Roda JC
# 105
# 2008–09
# Heerenveen
# Twente
# 106
# 2009–10
# Ajax
# Feyenoord
# 108
# 2010–11
# Twente
# Ajax
# 109
# 2011–12
# PSV
# Heracles Almelo
# 110
# 2012–13
# AZ
# PSV
# 111
# 2013–14
# PEC Zwolle
# Ajax
# 112
# 2014–15
# FC Groningen
# PEC Zwolle
# 113
# 2015–16
# Feyenoord
# FC Utrecht
# 114
# 2016–17
# Vitesse
# AZ Alkmaar
# 115
# 2017–18
# Feyenoord
# AZ Alkmaar
# 116
# 2018–19
# Ajax
# Willem II
